# %% [markdown]
# [index](./index.ipynb) | [yhoo-profile](./profile.ipynb) | [yhoo-financials](./financials.ipynb) | [yhoo-holders](./holders.ipynb) | [yhoo-options](./options.ipynb) | [yhoo-history](./history.ipynb)

# %% [markdown]
# # Virtual finance API
#
#
# The Yahoo.finance.com `profile` data.

# %%
import virtual_finance_api as fa
import virtual_finance_api.endpoints.yahoo as yh
import json

# %% [markdown]
# ## Logging
#
# Optionally setup the logging. The standard logging levels apply: DEBUG, INFO, WARNING, ERROR, CRITICAL

# %%
import logging

logging.basicConfig(
    filename="/tmp/virtual_finance_api.log",
    level=logging.INFO,
    format='%(asctime)s [%(levelname)s] %(name)s : %(message)s',
)

# %% [raw]
# from IPython.core.display import display, HTML
#
# display(HTML("<style>.container { width:100% !important; }</style>"))

# %% [markdown]
# ## The client processing the requests ...

# %%
client = fa.Client()

# %%
ticker = 'IBM'

# %%
r = yh.Profile(ticker)
rv = client.request(r)
print(json.dumps(rv, indent=2))
# Out:
# {
#   "defaultKeyStatistics": {
#     "annualHoldingsTurnover": null,
#     "enterpriseToRevenue": 2.372,
#     "beta3Year": null,
#     "profitMargins": 0.07593,
#     "enterpriseToEbitda": 11.431,
#     "52WeekChange": 0.20765078,
#     "morningStarRiskRating": null,
#     "forwardEps": 12.08,
#     "revenueQuarterlyGrowth": null,
#     "sharesOutstanding": 893593984,
#     "fundInceptionDate": null,
#     "annualReportExpenseRatio": null,
#     "totalAssets": null,
#     "bookValue": 23.074,
#     "sharesShort": 29098388,
#     "sharesPercentSharesOut": 0.0326,
#     "fundFamily": null,
#     "lastFiscalYearEnd": 1609372800,
#     "heldPercentInstitutions": 0.58584,
#     "netIncomeToCommon": 5501000192,
#     "trailingEps": 6.233,
#     "lastDividendValue": 1.63,
#     "SandP52WeekChange": 0.5131594,
#     "priceToBook": 5.8997145,
#     "heldPercentInsiders": 0.0012800001,
#     "nextFiscalYearEnd": 1672444800,
#     "yield": null,
#     "mostRecentQuarter": 1609372800,
#     "shortRatio": 4.89,
#     "sharesShortPreviousMonthDate": 1613088000,
#     "floatShares": 891967749,
#     "beta": 1.245395,
#     "enterpriseValue": 174654357504,
#     "priceHint": 2,
#     "threeYearAverageReturn": null,
#     "lastSplitDate": 927763200,
#     "lastSplitFactor": "2:1",
#     "legalType": null,
#     "lastDividendDate": 1612828800,
#     "morningStarOverallRating": null,
#     "earningsQuarterlyGrowth": -0.631,
#     "priceToSalesTrailing12Months": null,
#     "dateShortInterest": 1615766400,
#     "pegRatio": 1.94,
#     "ytdReturn": null,
#     "forwardPE": 11.26904,
#     "maxAge": 1,
#     "lastCapGain": null,
#     "shortPercentOfFloat": 0.0326,
#     "sharesShortPriorMonth": 29057711,
#     "impliedSharesOutstanding": null,
#     "category": null,
#     "fiveYearAverageReturn": null
#   },
#   "details": null,
#   "summaryProfile": {
#     "zip": "10504",
#     "sector": "Technology",
#     "fullTimeEmployees": 345900,
#     "longBusinessSummary": "International Business Machines Corporation provides integrated solutions and services worldwide. Its Cloud & Cognitive Software segment offers software for vertical and domain-specific solutions in health, financial services, supply chain, and asset management, weather, and security software and services application areas; and customer information control system and storage, and analytics and integration software solutions to support client mission critical on-premise workloads in banking, airline, and retail industries. It also offers middleware and data platform software, including Red Hat that enables the operation of clients' hybrid multi-cloud environments; and Cloud Paks, WebSphere distributed, and analytics platform software, such as DB2 distributed, information integration, and enterprise content management, as well as IoT, Blockchain and AI/Watson platforms. The company's Global Business Services segment offers business consulting services; system integration, application management, maintenance, and support services for packaged software; and finance, procurement, talent and engagement, and industry-specific business process outsourcing services. Its Global Technology Services segment provides IT infrastructure and platform services; and project, managed, outsourcing, and cloud-delivered services for enterprise IT infrastructure environments; and IT infrastructure support services. The company's Systems segment offers servers for businesses, cloud service providers, and scientific computing organizations; data storage products and solutions; and z/OS, an enterprise operating system, as well as Linux. Its Global Financing segment provides lease, installment payment, loan financing, short-term working capital financing, and remanufacturing and remarketing services. The company was formerly known as Computing-Tabulating-Recording Co. The company was incorporated in 1911 and is headquartered in Armonk, New York.",
#     "city": "Armonk",
#     "phone": "914 499 1900",
#     "state": "NY",
#     "country": "United States",
#     "companyOfficers": [],
#     "website": "http://www.ibm.com",
#     "maxAge": 86400,
#     "address1": "One New Orchard Road",
#     "industry": "Information Technology Services"
#   },
#   "recommendationTrend": {
#     "trend": [
#       {
#         "period": "0m",
#         "strongBuy": 4,
#         "buy": 3,
#         "hold": 15,
#         "sell": 3,
#         "strongSell": 0
#       },
#       {
#         "period": "-1m",
#         "strongBuy": 4,
#         "buy": 1,
#         "hold": 10,
#         "sell": 2,
#         "strongSell": 0
#       },
#       {
#         "period": "-2m",
#         "strongBuy": 4,
#         "buy": 1,
#         "hold": 10,
#         "sell": 2,
#         "strongSell": 0
#       },
#       {
#         "period": "-3m",
#         "strongBuy": 3,
#         "buy": 3,
#         "hold": 16,
#         "sell": 4,
#         "strongSell": 1
#       }
#     ],
#     "maxAge": 86400
#   },
#   "financialsTemplate": {
#     "code": "N",
#     "maxAge": 1
#   },
#   "earnings": {
#     "maxAge": 86400,
#     "earningsChart": {
#       "quarterly": [
#         {
#           "date": "1Q2020",
#           "actual": 1.84,
#           "estimate": 1.79
#         },
#         {
#           "date": "2Q2020",
#           "actual": 2.18,
#           "estimate": 2.07
#         },
#         {
#           "date": "3Q2020",
#           "actual": 2.58,
#           "estimate": 2.58
#         },
#         {
#           "date": "4Q2020",
#           "actual": 2.07,
#           "estimate": 1.79
#         }
#       ],
#       "currentQuarterEstimate": 1.63,
#       "currentQuarterEstimateDate": "1Q",
#       "currentQuarterEstimateYear": 2021,
#       "earningsDate": [
#         1618790400
#       ]
#     },
#     "financialsChart": {
#       "yearly": [
#         {
#           "date": 2017,
#           "revenue": 79139000000,
#           "earnings": 5753000000
#         },
#         {
#           "date": 2018,
#           "revenue": 79591000000,
#           "earnings": 8728000000
#         },
#         {
#           "date": 2019,
#           "revenue": 77147000000,
#           "earnings": 9431000000
#         },
#         {
#           "date": 2020,
#           "revenue": 73621000000,
#           "earnings": 5590000000
#         }
#       ],
#       "quarterly": [
#         {
#           "date": "1Q2020",
#           "revenue": 17571000000,
#           "earnings": 1175000000
#         },
#         {
#           "date": "2Q2020",
#           "revenue": 18121000000,
#           "earnings": 1361000000
#         },
#         {
#           "date": "3Q2020",
#           "revenue": 17561000000,
#           "earnings": 1698000000
#         },
#         {
#           "date": "4Q2020",
#           "revenue": 20368000000,
#           "earnings": 1356000000
#         }
#       ]
#     },
#     "financialCurrency": "USD"
#   },
#   "price": {
#     "quoteSourceName": "Nasdaq Real Time Price",
#     "regularMarketOpen": 135.98,
#     "averageDailyVolume3Month": 6668222,
#     "exchange": "NYQ",
#     "regularMarketTime": 1617032454,
#     "volume24Hr": null,
#     "regularMarketDayHigh": 137.05,
#     "shortName": "International Business Machines",
#     "averageDailyVolume10Day": 5578900,
#     "longName": "International Business Machines Corporation",
#     "regularMarketChange": -0.25,
#     "currencySymbol": "$",
#     "regularMarketPreviousClose": 136.38,
#     "preMarketPrice": 135.8,
#     "preMarketTime": 1617024591,
#     "exchangeDataDelayedBy": 0,
#     "toCurrency": null,
#     "postMarketChange": null,
#     "postMarketPrice": null,
#     "exchangeName": "NYSE",
#     "preMarketChange": -0.580002,
#     "circulatingSupply": null,
#     "regularMarketDayLow": 135.57,
#     "priceHint": 2,
#     "currency": "USD",
#     "regularMarketPrice": 136.13,
#     "regularMarketVolume": 1596290,
#     "lastMarket": null,
#     "regularMarketSource": "FREE_REALTIME",
#     "openInterest": null,
#     "marketState": "REGULAR",
#     "underlyingSymbol": null,
#     "marketCap": 121644949504,
#     "quoteType": "EQUITY",
#     "preMarketChangePercent": -0.00425284,
#     "volumeAllCurrencies": null,
#     "strikePrice": null,
#     "symbol": "IBM",
#     "preMarketSource": "FREE_REALTIME",
#     "maxAge": 1,
#     "fromCurrency": null,
#     "regularMarketChangePercent": -0.0018331133
#   },
#   "financialData": {
#     "ebitdaMargins": 0.20753,
#     "profitMargins": 0.07593,
#     "grossMargins": 0.48321998,
#     "operatingCashflow": 18197000192,
#     "revenueGrowth": -0.065,
#     "operatingMargins": 0.1166,
#     "ebitda": 15278999552,
#     "targetLowPrice": 115,
#     "recommendationKey": "hold",
#     "grossProfits": 35575000000,
#     "freeCashflow": 16965999616,
#     "targetMedianPrice": 140,
#     "currentPrice": 136.13,
#     "earningsGrowth": -0.631,
#     "currentRatio": 0.982,
#     "returnOnAssets": 0.03482,
#     "numberOfAnalystOpinions": 16,
#     "targetMeanPrice": 137.84,
#     "debtToEquity": 320.703,
#     "returnOnEquity": 0.26377,
#     "targetHighPrice": 165,
#     "totalCash": 13811999744,
#     "totalDebt": 66468999168,
#     "totalRevenue": 73620996096,
#     "totalCashPerShare": 15.457,
#     "financialCurrency": "USD",
#     "maxAge": 86400,
#     "revenuePerShare": 82.688,
#     "quickRatio": 0.829,
#     "recommendationMean": 2.6
#   },
#   "quoteType": {
#     "exchange": "NYQ",
#     "shortName": "International Business Machines",
#     "longName": "International Business Machines Corporation",
#     "exchangeTimezoneName": "America/New_York",
#     "exchangeTimezoneShortName": "EDT",
#     "isEsgPopulated": false,
#     "gmtOffSetMilliseconds": "-14400000",
#     "quoteType": "EQUITY",
#     "symbol": "IBM",
#     "messageBoardId": "finmb_112350",
#     "market": "us_market"
#   },
#   "calendarEvents": {
#     "maxAge": 1,
#     "earnings": {
#       "earningsDate": [
#         1618790400
#       ],
#       "earningsAverage": 1.63,
#       "earningsLow": 1.39,
#       "earningsHigh": 1.82,
#       "revenueAverage": 17377200000,
#       "revenueLow": 17108000000,
#       "revenueHigh": 17607300000
#     },
#     "exDividendDate": 1612828800,
#     "dividendDate": 1615334400
#   },
#   "summaryDetail": {
#     "previousClose": 136.38,
#     "regularMarketOpen": 135.98,
#     "twoHundredDayAverage": 122.54584,
#     "trailingAnnualDividendYield": 0.04773427,
#     "payoutRatio": 1.0619999,
#     "volume24Hr": null,
#     "regularMarketDayHigh": 137.05,
#     "navPrice": null,
#     "averageDailyVolume10Day": 5578900,
#     "totalAssets": null,
#     "regularMarketPreviousClose": 136.38,
#     "fiftyDayAverage": 124.69029,
#     "trailingAnnualDividendRate": 6.51,
#     "open": 135.98,
#     "toCurrency": null,
#     "averageVolume10days": 5578900,
#     "expireDate": null,
#     "yield": null,
#     "algorithm": null,
#     "dividendRate": 6.52,
#     "exDividendDate": 1612828800,
#     "beta": 1.245395,
#     "circulatingSupply": null,
#     "startDate": null,
#     "regularMarketDayLow": 135.57,
#     "priceHint": 2,
#     "currency": "USD",
#     "trailingPE": 21.840206,
#     "regularMarketVolume": 1596290,
#     "lastMarket": null,
#     "maxSupply": null,
#     "openInterest": null,
#     "marketCap": 121644949504,
#     "volumeAllCurrencies": null,
#     "strikePrice": null,
#     "averageVolume": 6668222,
#     "priceToSalesTrailing12Months": 1.6523132,
#     "dayLow": 135.57,
#     "ask": 135.79,
#     "ytdReturn": null,
#     "askSize": 1400,
#     "volume": 1596290,
#     "fiftyTwoWeekHigh": 137.05,
#     "forwardPE": 11.26904,
#     "maxAge": 1,
#     "fromCurrency": null,
#     "fiveYearAvgDividendYield": 4.33,
#     "fiftyTwoWeekLow": 104.52,
#     "bid": 135.81,
#     "tradeable": false,
#     "dividendYield": 0.0478,
#     "bidSize": 900,
#     "dayHigh": 137.05
#   },
#   "symbol": "IBM",
#   "esgScores": {
#     "palmOil": false,
#     "peerSocialPerformance": {
#       "min": 3.9,
#       "avg": 10.493564356435645,
#       "max": 17.93
#     },
#     "controversialWeapons": false,
#     "ratingMonth": 3,
#     "gambling": false,
#     "socialScore": 10.08,
#     "nuclear": false,
#     "furLeather": false,
#     "alcoholic": false,
#     "gmo": false,
#     "catholic": false,
#     "socialPercentile": null,
#     "peerGovernancePerformance": {
#       "min": 4.18,
#       "avg": 7.276237623762375,
#       "max": 33.22
#     },
#     "peerCount": 103,
#     "relatedControversy": [
#       "Employee Incidents",
#       "Customer Incidents",
#       "Business Ethics Incidents"
#     ],
#     "governanceScore": 7.39,
#     "environmentPercentile": null,
#     "animalTesting": false,
#     "peerEsgScorePerformance": {
#       "min": 10.19,
#       "avg": 18.86601941747573,
#       "max": 45
#     },
#     "tobacco": false,
#     "totalEsg": 17.88,
#     "highestControversy": 2,
#     "esgPerformance": "UNDER_PERF",
#     "coal": false,
#     "peerHighestControversyPerformance": {
#       "min": 0,
#       "avg": 1.4660194174757282,
#       "max": 5
#     },
#     "pesticides": false,
#     "adult": false,
#     "ratingYear": 2021,
#     "maxAge": 86400,
#     "percentile": 14.92,
#     "peerGroup": "Software & Services",
#     "smallArms": false,
#     "peerEnvironmentPerformance": {
#       "min": 0,
#       "avg": 0.9888118811881185,
#       "max": 3.67
#     },
#     "environmentScore": 0.41,
#     "governancePercentile": null,
#     "militaryContract": false
#   },
#   "upgradeDowngradeHistory": {
#     "history": [
#       {
#         "epochGradeDate": 1603210621,
#         "firm": "BMO Capital",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1602245772,
#         "firm": "Morgan Stanley",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1595423859,
#         "firm": "Argus Research",
#         "toGrade": "Buy",
#         "fromGrade": "Hold",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1595337540,
#         "firm": "Morgan Stanley",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1595337378,
#         "firm": "Credit Suisse",
#         "toGrade": "Outperform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1587572973,
#         "firm": "Citigroup",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1587481869,
#         "firm": "UBS",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1587472015,
#         "firm": "Morgan Stanley",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1587479348,
#         "firm": "Wedbush",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1586959964,
#         "firm": "Stifel",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1586953551,
#         "firm": "Credit Suisse",
#         "toGrade": "Outperform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1586872308,
#         "firm": "Wells Fargo",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1585163241,
#         "firm": "Morgan Stanley",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1584973665,
#         "firm": "Nomura",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1580755983,
#         "firm": "Edward Jones",
#         "toGrade": "Buy",
#         "fromGrade": "Hold",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1579703271,
#         "firm": "Morgan Stanley",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1579701598,
#         "firm": "Cantor Fitzgerald",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1579698302,
#         "firm": "Citigroup",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1579261087,
#         "firm": "Morgan Stanley",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "Overweight",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1578917505,
#         "firm": "Evercore ISI Group",
#         "toGrade": "In-Line",
#         "fromGrade": "Outperform",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1571656145,
#         "firm": "UBS",
#         "toGrade": "Neutral",
#         "fromGrade": "Buy",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1571323034,
#         "firm": "Wells Fargo",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1571312292,
#         "firm": "BMO Capital",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1571312247,
#         "firm": "Wedbush",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1571311135,
#         "firm": "Nomura",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1565098601,
#         "firm": "Wells Fargo",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1565006540,
#         "firm": "Nomura",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1565005796,
#         "firm": "Bank of America",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1563453616,
#         "firm": "Nomura",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1559819467,
#         "firm": "Evercore ISI Group",
#         "toGrade": "Outperform",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1555512957,
#         "firm": "Citigroup",
#         "toGrade": "Neutral",
#         "fromGrade": "Neutral",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1555511959,
#         "firm": "BMO Capital",
#         "toGrade": "Market Perform",
#         "fromGrade": "Market Perform",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1554985259,
#         "firm": "Credit Suisse",
#         "toGrade": "Outperform",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1545053936,
#         "firm": "RBC Capital",
#         "toGrade": "Outperform",
#         "fromGrade": "Outperform",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1540906594,
#         "firm": "UBS",
#         "toGrade": "Buy",
#         "fromGrade": "Buy",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1539872574,
#         "firm": "Argus",
#         "toGrade": "Hold",
#         "fromGrade": "Buy",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1539782367,
#         "firm": "Cantor Fitzgerald",
#         "toGrade": "Neutral",
#         "fromGrade": "Neutral",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1539777360,
#         "firm": "BMO Capital",
#         "toGrade": "Market Perform",
#         "fromGrade": "Market Perform",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1538659590,
#         "firm": "Moffett Nathanson",
#         "toGrade": "Sell",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1537966715,
#         "firm": "UBS",
#         "toGrade": "Buy",
#         "fromGrade": "Neutral",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1532003564,
#         "firm": "Morgan Stanley",
#         "toGrade": "Overweight",
#         "fromGrade": "Overweight",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1532001932,
#         "firm": "BMO Capital",
#         "toGrade": "Market Perform",
#         "fromGrade": "Market Perform",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1532001370,
#         "firm": "Stifel Nicolaus",
#         "toGrade": "Buy",
#         "fromGrade": "Buy",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1530180444,
#         "firm": "Nomura",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1516189602,
#         "firm": "Barclays",
#         "toGrade": "Overweight",
#         "fromGrade": "Underweight",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1514985227,
#         "firm": "RBC Capital",
#         "toGrade": "Outperform",
#         "fromGrade": "Sector Perform",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1509110309,
#         "firm": "Pivotal Research",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1508343902,
#         "firm": "Barclays",
#         "toGrade": "Underweight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1508338745,
#         "firm": "BMO Capital",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1508328536,
#         "firm": "Citigroup",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1508325395,
#         "firm": "UBS",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1501846840,
#         "firm": "Wedbush",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1500660977,
#         "firm": "Argus",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1500484494,
#         "firm": "Standpoint Research",
#         "toGrade": "Buy",
#         "fromGrade": "Hold",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1495192900,
#         "firm": "Pacific Crest",
#         "toGrade": "Sector Weight",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1491301123,
#         "firm": "Berenberg",
#         "toGrade": "Sell",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1490181106,
#         "firm": "Argus",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "reit"
#       },
#       {
#         "epochGradeDate": 1483540410,
#         "firm": "Guggenheim",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1478780189,
#         "firm": "Bank of America",
#         "toGrade": "Buy",
#         "fromGrade": "Neutral",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1476786354,
#         "firm": "Goldman Sachs",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1476257278,
#         "firm": "Credit Suisse",
#         "toGrade": "Underperform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1474891004,
#         "firm": "Societe Generale",
#         "toGrade": "Hold",
#         "fromGrade": "Sell",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1471321916,
#         "firm": "Oppenheimer",
#         "toGrade": "Perform",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1469457640,
#         "firm": "Standpoint Research",
#         "toGrade": "Hold",
#         "fromGrade": "Buy",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1468914809,
#         "firm": "BMO Capital",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468913177,
#         "firm": "Bernstein",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468913056,
#         "firm": "Jefferies",
#         "toGrade": "Underperform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468912850,
#         "firm": "Deutsche Bank",
#         "toGrade": "Hold",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468912786,
#         "firm": "JMP Securities",
#         "toGrade": "Market Outperform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468909711,
#         "firm": "UBS",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468907709,
#         "firm": "Morgan Stanley",
#         "toGrade": "Overweight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468905876,
#         "firm": "Drexel Hamilton",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468905570,
#         "firm": "Barclays",
#         "toGrade": "Underweight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468905545,
#         "firm": "Citigroup",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468905523,
#         "firm": "Credit Suisse",
#         "toGrade": "Underperform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468905498,
#         "firm": "Goldman Sachs",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468621677,
#         "firm": "Barclays",
#         "toGrade": "Underweight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1461073980,
#         "firm": "JP Morgan",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1461054906,
#         "firm": "Cantor Fitzgerald",
#         "toGrade": "Hold",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1461054760,
#         "firm": "Drexel Hamilton",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1461053473,
#         "firm": "Bernstein",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1461052612,
#         "firm": "Goldman Sachs",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1459403729,
#         "firm": "Morgan Stanley",
#         "toGrade": "Overweight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1455767921,
#         "firm": "Morgan Stanley",
#         "toGrade": "Overweight",
#         "fromGrade": "Equal-Weight",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1453291466,
#         "firm": "Deutsche Bank",
#         "toGrade": "Hold",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1453287855,
#         "firm": "Barclays",
#         "toGrade": "Underweight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1453277012,
#         "firm": "JMP Securities",
#         "toGrade": "Outperform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1453261866,
#         "firm": "Credit Suisse",
#         "toGrade": "Underperform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1447997340,
#         "firm": "JMP Securities",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1445439327,
#         "firm": "Citigroup",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1445345208,
#         "firm": "Stifel Nicolaus",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1445344248,
#         "firm": "Deutsche Bank",
#         "toGrade": "Hold",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1445331992,
#         "firm": "BMO Capital",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1444839969,
#         "firm": "Barclays",
#         "toGrade": "Underweight",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1443757366,
#         "firm": "JP Morgan",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1525527135,
#         "firm": "Argus",
#         "toGrade": "Buy",
#         "fromGrade": "Hold",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1425280062,
#         "firm": "Atlantic Equities",
#         "toGrade": "Underweight",
#         "fromGrade": "Neutral",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1421830800,
#         "firm": "Stifel Nicolaus",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1421312400,
#         "firm": "JP Morgan",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1421226000,
#         "firm": "Barclays",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1421053200,
#         "firm": "Deutsche Bank",
#         "toGrade": "Hold",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1419292800,
#         "firm": "Standpoint Research",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1413886318,
#         "firm": "Evercore Partners",
#         "toGrade": "Hold",
#         "fromGrade": "Buy",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1413880200,
#         "firm": "Barclays",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1412064522,
#         "firm": "CLSA",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1405726254,
#         "firm": "UBS",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1405715608,
#         "firm": "Barclays",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1398326400,
#         "firm": "J. Safra Sarasin",
#         "toGrade": "Neutral",
#         "fromGrade": "Buy",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1397720932,
#         "firm": "Stifel Nicolaus",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1397606044,
#         "firm": "Citigroup",
#         "toGrade": "Hold",
#         "fromGrade": "Buy",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1397548800,
#         "firm": "Citigroup",
#         "toGrade": "Neutral",
#         "fromGrade": "Buy",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1397117564,
#         "firm": "Deutsche Bank",
#         "toGrade": "Hold",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1386345600,
#         "firm": "Cowen & Co.",
#         "toGrade": "Market Perform",
#         "fromGrade": "Outperform",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1382081642,
#         "firm": "Argus Capital",
#         "toGrade": "Hold",
#         "fromGrade": "Buy",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1382025600,
#         "firm": "UBS",
#         "toGrade": "Neutral",
#         "fromGrade": "Buy",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1381992920,
#         "firm": "Citigroup",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1381992163,
#         "firm": "Deutsche Bank",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1381736734,
#         "firm": "Stifel Nicolaus",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1381127255,
#         "firm": "Barclays",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "Overweight",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1379608061,
#         "firm": "Cantor Fitzgerald",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1378737921,
#         "firm": "S&P Capital IQ",
#         "toGrade": "Strong Buy",
#         "fromGrade": "Buy",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1375773594,
#         "firm": "Credit Suisse",
#         "toGrade": "Underperform",
#         "fromGrade": "Neutral",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1373874590,
#         "firm": "Jefferies",
#         "toGrade": "Hold",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1373618069,
#         "firm": "Stifel Nicolaus",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1373354850,
#         "firm": "Goldman Sachs",
#         "toGrade": "Neutral",
#         "fromGrade": "Buy",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1366618519,
#         "firm": "Societe Generale",
#         "toGrade": "Hold",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1366359877,
#         "firm": "Stifel Nicolaus",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1366358818,
#         "firm": "Deutsche Bank",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1366357495,
#         "firm": "BMO Capital",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1365581464,
#         "firm": "UBS",
#         "toGrade": "Buy",
#         "fromGrade": "Neutral",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1358928704,
#         "firm": "BMO Capital",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1358922407,
#         "firm": "Societe Generale",
#         "toGrade": "Hold",
#         "fromGrade": "Sell",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1358497101,
#         "firm": "BMO Capital",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1358239088,
#         "firm": "Stifel",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1358145948,
#         "firm": "JP Morgan",
#         "toGrade": "Neutral",
#         "fromGrade": "Overweight",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1356074137,
#         "firm": "Topeka",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1350474660,
#         "firm": "UBS",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1350470280,
#         "firm": "Janney Capital",
#         "toGrade": "Neutral",
#         "fromGrade": "Buy",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1350453300,
#         "firm": "Societe Generale",
#         "toGrade": "Sell",
#         "fromGrade": "Hold",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1349712780,
#         "firm": "Citigroup",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1349073660,
#         "firm": "Deutsche Bank",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1348209240,
#         "firm": "Jefferies",
#         "toGrade": "Hold",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1346763480,
#         "firm": "Barclays",
#         "toGrade": "Overweight",
#         "fromGrade": "Equal-Weight",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1345793220,
#         "firm": "JP Morgan",
#         "toGrade": "Overweight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1342700940,
#         "firm": "UBS",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1342692540,
#         "firm": "Goldman Sachs",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1342678140,
#         "firm": "Deutsche Bank",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1341992700,
#         "firm": "Stifel Nicolaus",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1341990300,
#         "firm": "UBS",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1339416840,
#         "firm": "Barclays",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1334738100,
#         "firm": "Citigroup",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1334729880,
#         "firm": "Canaccord Genuity",
#         "toGrade": "Hold",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1334556720,
#         "firm": "Credit Suisse",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1333519200,
#         "firm": "Bank oferica",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1333439520,
#         "firm": "JP Morgan",
#         "toGrade": "Overweight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1332503040,
#         "firm": "UBS",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1331738940,
#         "firm": "Oxen Group",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "init"
#       }
#     ],
#     "maxAge": 86400
#   },
#   "pageViews": {
#     "shortTermTrend": "UP",
#     "midTermTrend": "UP",
#     "longTermTrend": "UP",
#     "maxAge": 1
#   }
# }

# %% [markdown]
# ## profile endpoint: yfinance compatible Profile request
#
# The `compat.yfinance` module offers a `Profile request` that is compatible with `yfinance`. It is derived from the `yahoo.Profile` class, but it offers properties to access the information sections of the Profile data.

# %%
import virtual_finance_api.compat.yfinance.endpoints as yf

# %%
r = yf.Profile(ticker)
rv = client.request(r)

# %%
print(json.dumps(rv, indent=2))
# Out:
# {
#   "defaultKeyStatistics": {
#     "annualHoldingsTurnover": null,
#     "enterpriseToRevenue": 2.372,
#     "beta3Year": null,
#     "profitMargins": 0.07593,
#     "enterpriseToEbitda": 11.431,
#     "52WeekChange": 0.20765078,
#     "morningStarRiskRating": null,
#     "forwardEps": 12.08,
#     "revenueQuarterlyGrowth": null,
#     "sharesOutstanding": 893593984,
#     "fundInceptionDate": null,
#     "annualReportExpenseRatio": null,
#     "totalAssets": null,
#     "bookValue": 23.074,
#     "sharesShort": 29098388,
#     "sharesPercentSharesOut": 0.0326,
#     "fundFamily": null,
#     "lastFiscalYearEnd": 1609372800,
#     "heldPercentInstitutions": 0.58584,
#     "netIncomeToCommon": 5501000192,
#     "trailingEps": 6.233,
#     "lastDividendValue": 1.63,
#     "SandP52WeekChange": 0.5131594,
#     "priceToBook": 5.8979373,
#     "heldPercentInsiders": 0.0012800001,
#     "nextFiscalYearEnd": 1672444800,
#     "yield": null,
#     "mostRecentQuarter": 1609372800,
#     "shortRatio": 4.89,
#     "sharesShortPreviousMonthDate": 1613088000,
#     "floatShares": 891967749,
#     "beta": 1.245395,
#     "enterpriseValue": 174654357504,
#     "priceHint": 2,
#     "threeYearAverageReturn": null,
#     "lastSplitDate": 927763200,
#     "lastSplitFactor": "2:1",
#     "legalType": null,
#     "lastDividendDate": 1612828800,
#     "morningStarOverallRating": null,
#     "earningsQuarterlyGrowth": -0.631,
#     "priceToSalesTrailing12Months": null,
#     "dateShortInterest": 1615766400,
#     "pegRatio": 1.94,
#     "ytdReturn": null,
#     "forwardPE": 11.265646,
#     "maxAge": 1,
#     "lastCapGain": null,
#     "shortPercentOfFloat": 0.0326,
#     "sharesShortPriorMonth": 29057711,
#     "impliedSharesOutstanding": null,
#     "category": null,
#     "fiveYearAverageReturn": null
#   },
#   "details": null,
#   "summaryProfile": {
#     "zip": "10504",
#     "sector": "Technology",
#     "fullTimeEmployees": 345900,
#     "longBusinessSummary": "International Business Machines Corporation provides integrated solutions and services worldwide. Its Cloud & Cognitive Software segment offers software for vertical and domain-specific solutions in health, financial services, supply chain, and asset management, weather, and security software and services application areas; and customer information control system and storage, and analytics and integration software solutions to support client mission critical on-premise workloads in banking, airline, and retail industries. It also offers middleware and data platform software, including Red Hat that enables the operation of clients' hybrid multi-cloud environments; and Cloud Paks, WebSphere distributed, and analytics platform software, such as DB2 distributed, information integration, and enterprise content management, as well as IoT, Blockchain and AI/Watson platforms. The company's Global Business Services segment offers business consulting services; system integration, application management, maintenance, and support services for packaged software; and finance, procurement, talent and engagement, and industry-specific business process outsourcing services. Its Global Technology Services segment provides IT infrastructure and platform services; and project, managed, outsourcing, and cloud-delivered services for enterprise IT infrastructure environments; and IT infrastructure support services. The company's Systems segment offers servers for businesses, cloud service providers, and scientific computing organizations; data storage products and solutions; and z/OS, an enterprise operating system, as well as Linux. Its Global Financing segment provides lease, installment payment, loan financing, short-term working capital financing, and remanufacturing and remarketing services. The company was formerly known as Computing-Tabulating-Recording Co. The company was incorporated in 1911 and is headquartered in Armonk, New York.",
#     "city": "Armonk",
#     "phone": "914 499 1900",
#     "state": "NY",
#     "country": "United States",
#     "companyOfficers": [],
#     "website": "http://www.ibm.com",
#     "maxAge": 86400,
#     "address1": "One New Orchard Road",
#     "industry": "Information Technology Services"
#   },
#   "recommendationTrend": {
#     "trend": [
#       {
#         "period": "0m",
#         "strongBuy": 4,
#         "buy": 3,
#         "hold": 15,
#         "sell": 3,
#         "strongSell": 0
#       },
#       {
#         "period": "-1m",
#         "strongBuy": 4,
#         "buy": 1,
#         "hold": 10,
#         "sell": 2,
#         "strongSell": 0
#       },
#       {
#         "period": "-2m",
#         "strongBuy": 4,
#         "buy": 1,
#         "hold": 10,
#         "sell": 2,
#         "strongSell": 0
#       },
#       {
#         "period": "-3m",
#         "strongBuy": 3,
#         "buy": 3,
#         "hold": 16,
#         "sell": 4,
#         "strongSell": 1
#       }
#     ],
#     "maxAge": 86400
#   },
#   "financialsTemplate": {
#     "code": "N",
#     "maxAge": 1
#   },
#   "earnings": {
#     "maxAge": 86400,
#     "earningsChart": {
#       "quarterly": [
#         {
#           "date": "1Q2020",
#           "actual": 1.84,
#           "estimate": 1.79
#         },
#         {
#           "date": "2Q2020",
#           "actual": 2.18,
#           "estimate": 2.07
#         },
#         {
#           "date": "3Q2020",
#           "actual": 2.58,
#           "estimate": 2.58
#         },
#         {
#           "date": "4Q2020",
#           "actual": 2.07,
#           "estimate": 1.79
#         }
#       ],
#       "currentQuarterEstimate": 1.63,
#       "currentQuarterEstimateDate": "1Q",
#       "currentQuarterEstimateYear": 2021,
#       "earningsDate": [
#         1618790400
#       ]
#     },
#     "financialsChart": {
#       "yearly": [
#         {
#           "date": 2017,
#           "revenue": 79139000000,
#           "earnings": 5753000000
#         },
#         {
#           "date": 2018,
#           "revenue": 79591000000,
#           "earnings": 8728000000
#         },
#         {
#           "date": 2019,
#           "revenue": 77147000000,
#           "earnings": 9431000000
#         },
#         {
#           "date": 2020,
#           "revenue": 73621000000,
#           "earnings": 5590000000
#         }
#       ],
#       "quarterly": [
#         {
#           "date": "1Q2020",
#           "revenue": 17571000000,
#           "earnings": 1175000000
#         },
#         {
#           "date": "2Q2020",
#           "revenue": 18121000000,
#           "earnings": 1361000000
#         },
#         {
#           "date": "3Q2020",
#           "revenue": 17561000000,
#           "earnings": 1698000000
#         },
#         {
#           "date": "4Q2020",
#           "revenue": 20368000000,
#           "earnings": 1356000000
#         }
#       ]
#     },
#     "financialCurrency": "USD"
#   },
#   "price": {
#     "quoteSourceName": "Nasdaq Real Time Price",
#     "regularMarketOpen": 135.98,
#     "averageDailyVolume3Month": 6668222,
#     "exchange": "NYQ",
#     "regularMarketTime": 1617032491,
#     "volume24Hr": null,
#     "regularMarketDayHigh": 137.05,
#     "shortName": "International Business Machines",
#     "averageDailyVolume10Day": 5578900,
#     "longName": "International Business Machines Corporation",
#     "regularMarketChange": -0.29100037,
#     "currencySymbol": "$",
#     "regularMarketPreviousClose": 136.38,
#     "preMarketPrice": 135.8,
#     "preMarketTime": 1617024591,
#     "exchangeDataDelayedBy": 0,
#     "toCurrency": null,
#     "postMarketChange": null,
#     "postMarketPrice": null,
#     "exchangeName": "NYSE",
#     "preMarketChange": -0.580002,
#     "circulatingSupply": null,
#     "regularMarketDayLow": 135.57,
#     "priceHint": 2,
#     "currency": "USD",
#     "regularMarketPrice": 136.089,
#     "regularMarketVolume": 1599557,
#     "lastMarket": null,
#     "regularMarketSource": "FREE_REALTIME",
#     "openInterest": null,
#     "marketState": "REGULAR",
#     "underlyingSymbol": null,
#     "marketCap": 121608314880,
#     "quoteType": "EQUITY",
#     "preMarketChangePercent": -0.00425284,
#     "volumeAllCurrencies": null,
#     "strikePrice": null,
#     "symbol": "IBM",
#     "preMarketSource": "FREE_REALTIME",
#     "maxAge": 1,
#     "fromCurrency": null,
#     "regularMarketChangePercent": -0.0021337466
#   },
#   "financialData": {
#     "ebitdaMargins": 0.20753,
#     "profitMargins": 0.07593,
#     "grossMargins": 0.48321998,
#     "operatingCashflow": 18197000192,
#     "revenueGrowth": -0.065,
#     "operatingMargins": 0.1166,
#     "ebitda": 15278999552,
#     "targetLowPrice": 115,
#     "recommendationKey": "hold",
#     "grossProfits": 35575000000,
#     "freeCashflow": 16965999616,
#     "targetMedianPrice": 140,
#     "currentPrice": 136.089,
#     "earningsGrowth": -0.631,
#     "currentRatio": 0.982,
#     "returnOnAssets": 0.03482,
#     "numberOfAnalystOpinions": 16,
#     "targetMeanPrice": 137.84,
#     "debtToEquity": 320.703,
#     "returnOnEquity": 0.26377,
#     "targetHighPrice": 165,
#     "totalCash": 13811999744,
#     "totalDebt": 66468999168,
#     "totalRevenue": 73620996096,
#     "totalCashPerShare": 15.457,
#     "financialCurrency": "USD",
#     "maxAge": 86400,
#     "revenuePerShare": 82.688,
#     "quickRatio": 0.829,
#     "recommendationMean": 2.6
#   },
#   "quoteType": {
#     "exchange": "NYQ",
#     "shortName": "International Business Machines",
#     "longName": "International Business Machines Corporation",
#     "exchangeTimezoneName": "America/New_York",
#     "exchangeTimezoneShortName": "EDT",
#     "isEsgPopulated": false,
#     "gmtOffSetMilliseconds": "-14400000",
#     "quoteType": "EQUITY",
#     "symbol": "IBM",
#     "messageBoardId": "finmb_112350",
#     "market": "us_market"
#   },
#   "calendarEvents": {
#     "maxAge": 1,
#     "earnings": {
#       "earningsDate": [
#         1618790400
#       ],
#       "earningsAverage": 1.63,
#       "earningsLow": 1.39,
#       "earningsHigh": 1.82,
#       "revenueAverage": 17377200000,
#       "revenueLow": 17108000000,
#       "revenueHigh": 17607300000
#     },
#     "exDividendDate": 1612828800,
#     "dividendDate": 1615334400
#   },
#   "summaryDetail": {
#     "previousClose": 136.38,
#     "regularMarketOpen": 135.98,
#     "twoHundredDayAverage": 122.54584,
#     "trailingAnnualDividendYield": 0.04773427,
#     "payoutRatio": 1.0619999,
#     "volume24Hr": null,
#     "regularMarketDayHigh": 137.05,
#     "navPrice": null,
#     "averageDailyVolume10Day": 5578900,
#     "totalAssets": null,
#     "regularMarketPreviousClose": 136.38,
#     "fiftyDayAverage": 124.69029,
#     "trailingAnnualDividendRate": 6.51,
#     "open": 135.98,
#     "toCurrency": null,
#     "averageVolume10days": 5578900,
#     "expireDate": null,
#     "yield": null,
#     "algorithm": null,
#     "dividendRate": 6.52,
#     "exDividendDate": 1612828800,
#     "beta": 1.245395,
#     "circulatingSupply": null,
#     "startDate": null,
#     "regularMarketDayLow": 135.57,
#     "priceHint": 2,
#     "currency": "USD",
#     "trailingPE": 21.83363,
#     "regularMarketVolume": 1599557,
#     "lastMarket": null,
#     "maxSupply": null,
#     "openInterest": null,
#     "marketCap": 121608314880,
#     "volumeAllCurrencies": null,
#     "strikePrice": null,
#     "averageVolume": 6668222,
#     "priceToSalesTrailing12Months": 1.6518157,
#     "dayLow": 135.57,
#     "ask": 135.83,
#     "ytdReturn": null,
#     "askSize": 1400,
#     "volume": 1599557,
#     "fiftyTwoWeekHigh": 137.05,
#     "forwardPE": 11.265646,
#     "maxAge": 1,
#     "fromCurrency": null,
#     "fiveYearAvgDividendYield": 4.33,
#     "fiftyTwoWeekLow": 104.52,
#     "bid": 135.77,
#     "tradeable": false,
#     "dividendYield": 0.0478,
#     "bidSize": 900,
#     "dayHigh": 137.05
#   },
#   "symbol": "IBM",
#   "esgScores": {
#     "palmOil": false,
#     "peerSocialPerformance": {
#       "min": 3.9,
#       "avg": 10.493564356435645,
#       "max": 17.93
#     },
#     "controversialWeapons": false,
#     "ratingMonth": 3,
#     "gambling": false,
#     "socialScore": 10.08,
#     "nuclear": false,
#     "furLeather": false,
#     "alcoholic": false,
#     "gmo": false,
#     "catholic": false,
#     "socialPercentile": null,
#     "peerGovernancePerformance": {
#       "min": 4.18,
#       "avg": 7.276237623762375,
#       "max": 33.22
#     },
#     "peerCount": 103,
#     "relatedControversy": [
#       "Employee Incidents",
#       "Customer Incidents",
#       "Business Ethics Incidents"
#     ],
#     "governanceScore": 7.39,
#     "environmentPercentile": null,
#     "animalTesting": false,
#     "peerEsgScorePerformance": {
#       "min": 10.19,
#       "avg": 18.86601941747573,
#       "max": 45
#     },
#     "tobacco": false,
#     "totalEsg": 17.88,
#     "highestControversy": 2,
#     "esgPerformance": "UNDER_PERF",
#     "coal": false,
#     "peerHighestControversyPerformance": {
#       "min": 0,
#       "avg": 1.4660194174757282,
#       "max": 5
#     },
#     "pesticides": false,
#     "adult": false,
#     "ratingYear": 2021,
#     "maxAge": 86400,
#     "percentile": 14.92,
#     "peerGroup": "Software & Services",
#     "smallArms": false,
#     "peerEnvironmentPerformance": {
#       "min": 0,
#       "avg": 0.9888118811881185,
#       "max": 3.67
#     },
#     "environmentScore": 0.41,
#     "governancePercentile": null,
#     "militaryContract": false
#   },
#   "upgradeDowngradeHistory": {
#     "history": [
#       {
#         "epochGradeDate": 1603210621,
#         "firm": "BMO Capital",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1602245772,
#         "firm": "Morgan Stanley",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1595423859,
#         "firm": "Argus Research",
#         "toGrade": "Buy",
#         "fromGrade": "Hold",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1595337540,
#         "firm": "Morgan Stanley",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1595337378,
#         "firm": "Credit Suisse",
#         "toGrade": "Outperform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1587572973,
#         "firm": "Citigroup",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1587481869,
#         "firm": "UBS",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1587472015,
#         "firm": "Morgan Stanley",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1587479348,
#         "firm": "Wedbush",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1586959964,
#         "firm": "Stifel",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1586953551,
#         "firm": "Credit Suisse",
#         "toGrade": "Outperform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1586872308,
#         "firm": "Wells Fargo",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1585163241,
#         "firm": "Morgan Stanley",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1584973665,
#         "firm": "Nomura",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1580755983,
#         "firm": "Edward Jones",
#         "toGrade": "Buy",
#         "fromGrade": "Hold",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1579703271,
#         "firm": "Morgan Stanley",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1579701598,
#         "firm": "Cantor Fitzgerald",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1579698302,
#         "firm": "Citigroup",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1579261087,
#         "firm": "Morgan Stanley",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "Overweight",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1578917505,
#         "firm": "Evercore ISI Group",
#         "toGrade": "In-Line",
#         "fromGrade": "Outperform",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1571656145,
#         "firm": "UBS",
#         "toGrade": "Neutral",
#         "fromGrade": "Buy",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1571323034,
#         "firm": "Wells Fargo",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1571312292,
#         "firm": "BMO Capital",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1571312247,
#         "firm": "Wedbush",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1571311135,
#         "firm": "Nomura",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1565098601,
#         "firm": "Wells Fargo",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1565006540,
#         "firm": "Nomura",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1565005796,
#         "firm": "Bank of America",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1563453616,
#         "firm": "Nomura",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1559819467,
#         "firm": "Evercore ISI Group",
#         "toGrade": "Outperform",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1555512957,
#         "firm": "Citigroup",
#         "toGrade": "Neutral",
#         "fromGrade": "Neutral",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1555511959,
#         "firm": "BMO Capital",
#         "toGrade": "Market Perform",
#         "fromGrade": "Market Perform",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1554985259,
#         "firm": "Credit Suisse",
#         "toGrade": "Outperform",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1545053936,
#         "firm": "RBC Capital",
#         "toGrade": "Outperform",
#         "fromGrade": "Outperform",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1540906594,
#         "firm": "UBS",
#         "toGrade": "Buy",
#         "fromGrade": "Buy",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1539872574,
#         "firm": "Argus",
#         "toGrade": "Hold",
#         "fromGrade": "Buy",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1539782367,
#         "firm": "Cantor Fitzgerald",
#         "toGrade": "Neutral",
#         "fromGrade": "Neutral",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1539777360,
#         "firm": "BMO Capital",
#         "toGrade": "Market Perform",
#         "fromGrade": "Market Perform",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1538659590,
#         "firm": "Moffett Nathanson",
#         "toGrade": "Sell",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1537966715,
#         "firm": "UBS",
#         "toGrade": "Buy",
#         "fromGrade": "Neutral",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1532003564,
#         "firm": "Morgan Stanley",
#         "toGrade": "Overweight",
#         "fromGrade": "Overweight",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1532001932,
#         "firm": "BMO Capital",
#         "toGrade": "Market Perform",
#         "fromGrade": "Market Perform",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1532001370,
#         "firm": "Stifel Nicolaus",
#         "toGrade": "Buy",
#         "fromGrade": "Buy",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1530180444,
#         "firm": "Nomura",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1516189602,
#         "firm": "Barclays",
#         "toGrade": "Overweight",
#         "fromGrade": "Underweight",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1514985227,
#         "firm": "RBC Capital",
#         "toGrade": "Outperform",
#         "fromGrade": "Sector Perform",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1509110309,
#         "firm": "Pivotal Research",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1508343902,
#         "firm": "Barclays",
#         "toGrade": "Underweight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1508338745,
#         "firm": "BMO Capital",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1508328536,
#         "firm": "Citigroup",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1508325395,
#         "firm": "UBS",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1501846840,
#         "firm": "Wedbush",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1500660977,
#         "firm": "Argus",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1500484494,
#         "firm": "Standpoint Research",
#         "toGrade": "Buy",
#         "fromGrade": "Hold",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1495192900,
#         "firm": "Pacific Crest",
#         "toGrade": "Sector Weight",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1491301123,
#         "firm": "Berenberg",
#         "toGrade": "Sell",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1490181106,
#         "firm": "Argus",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "reit"
#       },
#       {
#         "epochGradeDate": 1483540410,
#         "firm": "Guggenheim",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1478780189,
#         "firm": "Bank of America",
#         "toGrade": "Buy",
#         "fromGrade": "Neutral",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1476786354,
#         "firm": "Goldman Sachs",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1476257278,
#         "firm": "Credit Suisse",
#         "toGrade": "Underperform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1474891004,
#         "firm": "Societe Generale",
#         "toGrade": "Hold",
#         "fromGrade": "Sell",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1471321916,
#         "firm": "Oppenheimer",
#         "toGrade": "Perform",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1469457640,
#         "firm": "Standpoint Research",
#         "toGrade": "Hold",
#         "fromGrade": "Buy",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1468914809,
#         "firm": "BMO Capital",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468913177,
#         "firm": "Bernstein",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468913056,
#         "firm": "Jefferies",
#         "toGrade": "Underperform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468912850,
#         "firm": "Deutsche Bank",
#         "toGrade": "Hold",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468912786,
#         "firm": "JMP Securities",
#         "toGrade": "Market Outperform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468909711,
#         "firm": "UBS",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468907709,
#         "firm": "Morgan Stanley",
#         "toGrade": "Overweight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468905876,
#         "firm": "Drexel Hamilton",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468905570,
#         "firm": "Barclays",
#         "toGrade": "Underweight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468905545,
#         "firm": "Citigroup",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468905523,
#         "firm": "Credit Suisse",
#         "toGrade": "Underperform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468905498,
#         "firm": "Goldman Sachs",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1468621677,
#         "firm": "Barclays",
#         "toGrade": "Underweight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1461073980,
#         "firm": "JP Morgan",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1461054906,
#         "firm": "Cantor Fitzgerald",
#         "toGrade": "Hold",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1461054760,
#         "firm": "Drexel Hamilton",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1461053473,
#         "firm": "Bernstein",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1461052612,
#         "firm": "Goldman Sachs",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1459403729,
#         "firm": "Morgan Stanley",
#         "toGrade": "Overweight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1455767921,
#         "firm": "Morgan Stanley",
#         "toGrade": "Overweight",
#         "fromGrade": "Equal-Weight",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1453291466,
#         "firm": "Deutsche Bank",
#         "toGrade": "Hold",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1453287855,
#         "firm": "Barclays",
#         "toGrade": "Underweight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1453277012,
#         "firm": "JMP Securities",
#         "toGrade": "Outperform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1453261866,
#         "firm": "Credit Suisse",
#         "toGrade": "Underperform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1447997340,
#         "firm": "JMP Securities",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1445439327,
#         "firm": "Citigroup",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1445345208,
#         "firm": "Stifel Nicolaus",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1445344248,
#         "firm": "Deutsche Bank",
#         "toGrade": "Hold",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1445331992,
#         "firm": "BMO Capital",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1444839969,
#         "firm": "Barclays",
#         "toGrade": "Underweight",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1443757366,
#         "firm": "JP Morgan",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1525527135,
#         "firm": "Argus",
#         "toGrade": "Buy",
#         "fromGrade": "Hold",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1425280062,
#         "firm": "Atlantic Equities",
#         "toGrade": "Underweight",
#         "fromGrade": "Neutral",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1421830800,
#         "firm": "Stifel Nicolaus",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1421312400,
#         "firm": "JP Morgan",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1421226000,
#         "firm": "Barclays",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1421053200,
#         "firm": "Deutsche Bank",
#         "toGrade": "Hold",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1419292800,
#         "firm": "Standpoint Research",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1413886318,
#         "firm": "Evercore Partners",
#         "toGrade": "Hold",
#         "fromGrade": "Buy",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1413880200,
#         "firm": "Barclays",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1412064522,
#         "firm": "CLSA",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1405726254,
#         "firm": "UBS",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1405715608,
#         "firm": "Barclays",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1398326400,
#         "firm": "J. Safra Sarasin",
#         "toGrade": "Neutral",
#         "fromGrade": "Buy",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1397720932,
#         "firm": "Stifel Nicolaus",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1397606044,
#         "firm": "Citigroup",
#         "toGrade": "Hold",
#         "fromGrade": "Buy",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1397548800,
#         "firm": "Citigroup",
#         "toGrade": "Neutral",
#         "fromGrade": "Buy",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1397117564,
#         "firm": "Deutsche Bank",
#         "toGrade": "Hold",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1386345600,
#         "firm": "Cowen & Co.",
#         "toGrade": "Market Perform",
#         "fromGrade": "Outperform",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1382081642,
#         "firm": "Argus Capital",
#         "toGrade": "Hold",
#         "fromGrade": "Buy",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1382025600,
#         "firm": "UBS",
#         "toGrade": "Neutral",
#         "fromGrade": "Buy",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1381992920,
#         "firm": "Citigroup",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1381992163,
#         "firm": "Deutsche Bank",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1381736734,
#         "firm": "Stifel Nicolaus",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1381127255,
#         "firm": "Barclays",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "Overweight",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1379608061,
#         "firm": "Cantor Fitzgerald",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1378737921,
#         "firm": "S&P Capital IQ",
#         "toGrade": "Strong Buy",
#         "fromGrade": "Buy",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1375773594,
#         "firm": "Credit Suisse",
#         "toGrade": "Underperform",
#         "fromGrade": "Neutral",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1373874590,
#         "firm": "Jefferies",
#         "toGrade": "Hold",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1373618069,
#         "firm": "Stifel Nicolaus",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1373354850,
#         "firm": "Goldman Sachs",
#         "toGrade": "Neutral",
#         "fromGrade": "Buy",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1366618519,
#         "firm": "Societe Generale",
#         "toGrade": "Hold",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1366359877,
#         "firm": "Stifel Nicolaus",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1366358818,
#         "firm": "Deutsche Bank",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1366357495,
#         "firm": "BMO Capital",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1365581464,
#         "firm": "UBS",
#         "toGrade": "Buy",
#         "fromGrade": "Neutral",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1358928704,
#         "firm": "BMO Capital",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1358922407,
#         "firm": "Societe Generale",
#         "toGrade": "Hold",
#         "fromGrade": "Sell",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1358497101,
#         "firm": "BMO Capital",
#         "toGrade": "Market Perform",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1358239088,
#         "firm": "Stifel",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1358145948,
#         "firm": "JP Morgan",
#         "toGrade": "Neutral",
#         "fromGrade": "Overweight",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1356074137,
#         "firm": "Topeka",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1350474660,
#         "firm": "UBS",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1350470280,
#         "firm": "Janney Capital",
#         "toGrade": "Neutral",
#         "fromGrade": "Buy",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1350453300,
#         "firm": "Societe Generale",
#         "toGrade": "Sell",
#         "fromGrade": "Hold",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1349712780,
#         "firm": "Citigroup",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1349073660,
#         "firm": "Deutsche Bank",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1348209240,
#         "firm": "Jefferies",
#         "toGrade": "Hold",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1346763480,
#         "firm": "Barclays",
#         "toGrade": "Overweight",
#         "fromGrade": "Equal-Weight",
#         "action": "up"
#       },
#       {
#         "epochGradeDate": 1345793220,
#         "firm": "JP Morgan",
#         "toGrade": "Overweight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1342700940,
#         "firm": "UBS",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1342692540,
#         "firm": "Goldman Sachs",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1342678140,
#         "firm": "Deutsche Bank",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1341992700,
#         "firm": "Stifel Nicolaus",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1341990300,
#         "firm": "UBS",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "init"
#       },
#       {
#         "epochGradeDate": 1339416840,
#         "firm": "Barclays",
#         "toGrade": "Equal-Weight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1334738100,
#         "firm": "Citigroup",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1334729880,
#         "firm": "Canaccord Genuity",
#         "toGrade": "Hold",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1334556720,
#         "firm": "Credit Suisse",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1333519200,
#         "firm": "Bank oferica",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "down"
#       },
#       {
#         "epochGradeDate": 1333439520,
#         "firm": "JP Morgan",
#         "toGrade": "Overweight",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1332503040,
#         "firm": "UBS",
#         "toGrade": "Neutral",
#         "fromGrade": "",
#         "action": "main"
#       },
#       {
#         "epochGradeDate": 1331738940,
#         "firm": "Oxen Group",
#         "toGrade": "Buy",
#         "fromGrade": "",
#         "action": "init"
#       }
#     ],
#     "maxAge": 86400
#   },
#   "pageViews": {
#     "shortTermTrend": "UP",
#     "midTermTrend": "UP",
#     "longTermTrend": "UP",
#     "maxAge": 1
#   }
# }

# %% [markdown]
# Now that looks like the same response data.... and it is. But the `yfcompat.Profile` request class provides *properties* to extract information from the response just as `yfinance.Ticker`

# %%
print(r.sustainability)
# Out:
#                                      Value
# 2021-3
# palmOil                              False
# controversialWeapons                 False
# gambling                             False
# socialScore                          10.08
# nuclear                              False
# furLeather                           False
# alcoholic                            False
# gmo                                  False
# catholic                             False
# socialPercentile                      None
# peerCount                              103
# governanceScore                       7.39
# environmentPercentile                 None
# animalTesting                        False
# tobacco                              False
# totalEsg                             17.88
# highestControversy                       2
# esgPerformance                  UNDER_PERF
# coal                                 False
# pesticides                           False
# adult                                False
# percentile                           14.92
# peerGroup              Software & Services
# smallArms                            False
# environmentScore                      0.41
# governancePercentile                  None
# militaryContract                     False

# %%
print(r.recommendations)
# Out:
#                                Firm        To Grade From Grade Action
# Date
# 2012-03-14 15:29:00      Oxen Group             Buy              init
# 2012-03-23 11:44:00             UBS         Neutral              main
# 2012-04-03 07:52:00       JP Morgan      Overweight              main
# 2012-04-04 06:00:00    Bank oferica         Neutral              down
# 2012-04-16 06:12:00   Credit Suisse         Neutral              main
# ...                             ...             ...        ...    ...
# 2020-07-21 13:16:18   Credit Suisse      Outperform              main
# 2020-07-21 13:19:00  Morgan Stanley    Equal-Weight              main
# 2020-07-22 13:17:39  Argus Research             Buy       Hold     up
# 2020-10-09 12:16:12  Morgan Stanley    Equal-Weight              main
# 2020-10-20 16:17:01     BMO Capital  Market Perform              main
#
# [157 rows x 4 columns]

# %%
print(r.calendar)
# Out:
#                                 Value
# Earnings Date     2021-04-19 00:00:00
# Earnings Average                 1.63
# Earnings Low                     1.39
# Earnings High                    1.82
# Revenue Average           17377200000
# Revenue Low               17108000000
# Revenue High              17607300000

# %%
print(r.info)
# Out:
# {'zip': '10504', 'sector': 'Technology', 'fullTimeEmployees': 345900, 'longBusinessSummary': "International Business Machines Corporation provides integrated solutions and services worldwide. Its Cloud & Cognitive Software segment offers software for vertical and domain-specific solutions in health, financial services, supply chain, and asset management, weather, and security software and services application areas; and customer information control system and storage, and analytics and integration software solutions to support client mission critical on-premise workloads in banking, airline, and retail industries. It also offers middleware and data platform software, including Red Hat that enables the operation of clients' hybrid multi-cloud environments; and Cloud Paks, WebSphere distributed, and analytics platform software, such as DB2 distributed, information integration, and enterprise content management, as well as IoT, Blockchain and AI/Watson platforms. The company's Global Business Services segment offers business consulting services; system integration, application management, maintenance, and support services for packaged software; and finance, procurement, talent and engagement, and industry-specific business process outsourcing services. Its Global Technology Services segment provides IT infrastructure and platform services; and project, managed, outsourcing, and cloud-delivered services for enterprise IT infrastructure environments; and IT infrastructure support services. The company's Systems segment offers servers for businesses, cloud service providers, and scientific computing organizations; data storage products and solutions; and z/OS, an enterprise operating system, as well as Linux. Its Global Financing segment provides lease, installment payment, loan financing, short-term working capital financing, and remanufacturing and remarketing services. The company was formerly known as Computing-Tabulating-Recording Co. The company was incorporated in 1911 and is headquartered in Armonk, New York.", 'city': 'Armonk', 'phone': '914 499 1900', 'state': 'NY', 'country': 'United States', 'companyOfficers': [], 'website': 'http://www.ibm.com', 'maxAge': 1, 'address1': 'One New Orchard Road', 'industry': 'Information Technology Services', 'previousClose': 136.38, 'regularMarketOpen': 135.98, 'twoHundredDayAverage': 122.54584, 'trailingAnnualDividendYield': 0.04773427, 'payoutRatio': 1.0619999, 'volume24Hr': None, 'regularMarketDayHigh': 137.05, 'navPrice': None, 'averageDailyVolume10Day': 5578900, 'totalAssets': None, 'regularMarketPreviousClose': 136.38, 'fiftyDayAverage': 124.69029, 'trailingAnnualDividendRate': 6.51, 'open': 135.98, 'toCurrency': None, 'averageVolume10days': 5578900, 'expireDate': None, 'yield': None, 'algorithm': None, 'dividendRate': 6.52, 'exDividendDate': 1612828800, 'beta': 1.245395, 'circulatingSupply': None, 'startDate': None, 'regularMarketDayLow': 135.57, 'priceHint': 2, 'currency': 'USD', 'trailingPE': 21.83363, 'regularMarketVolume': 1599557, 'lastMarket': None, 'maxSupply': None, 'openInterest': None, 'marketCap': 121608314880, 'volumeAllCurrencies': None, 'strikePrice': None, 'averageVolume': 6668222, 'priceToSalesTrailing12Months': 1.6518157, 'dayLow': 135.57, 'ask': 135.83, 'ytdReturn': None, 'askSize': 1400, 'volume': 1599557, 'fiftyTwoWeekHigh': 137.05, 'forwardPE': 11.265646, 'fromCurrency': None, 'fiveYearAvgDividendYield': 4.33, 'fiftyTwoWeekLow': 104.52, 'bid': 135.77, 'tradeable': False, 'dividendYield': 0.0478, 'bidSize': 900, 'dayHigh': 137.05, 'exchange': 'NYQ', 'shortName': 'International Business Machines', 'longName': 'International Business Machines Corporation', 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EDT', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '-14400000', 'quoteType': 'EQUITY', 'symbol': 'IBM', 'messageBoardId': 'finmb_112350', 'market': 'us_market', 'annualHoldingsTurnover': None, 'enterpriseToRevenue': 2.372, 'beta3Year' ...

# %% [markdown]
# [index](./index.ipynb) | [yhoo-profile](./profile.ipynb) | [yhoo-financials](./financials.ipynb) | [yhoo-holders](./holders.ipynb) | [yhoo-options](./options.ipynb) | [yhoo-history](./history.ipynb)
