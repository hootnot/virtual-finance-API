# %% [markdown]
# [index](./index.ipynb) | [yhoo-profile](./profile.ipynb) | [yhoo-financials](./financials.ipynb) | [yhoo-holders](./holders.ipynb) | [yhoo-options](./options.ipynb) | [yhoo-history](./history.ipynb)

# %%
import virtual_finance_api as fa
import virtual_finance_api.endpoints.yahoo as yh
import json

# %%
import logging

logging.basicConfig(
    filename="/tmp/virtual_finance_api.log",
    level=logging.INFO,
    format='%(asctime)s [%(levelname)s] %(name)s : %(message)s',
)

# %% [raw]
# from IPython.core.display import display, HTML
#
# display(HTML("<style>.container { width:100% !important; }</style>"))

# %% [markdown]
# ## The client processing the requests ...

# %%
client = fa.Client()

# %%
ticker = 'IBM'

# %% [markdown]
# ## holders endpoint: the Holders request

# %%
r = yh.Holders(ticker)

# %%
print(json.dumps(client.request(r), indent=2))
# Out:
# {
#   "major": {
#     "0": {
#       "0": "0.13%",
#       "1": "58.58%",
#       "2": "58.66%",
#       "3": "2561"
#     },
#     "1": {
#       "0": "% of Shares Held by All Insider",
#       "1": "% of Shares Held by Institutions",
#       "2": "% of Float Held by Institutions",
#       "3": "Number of Institutions Holding Shares"
#     }
#   },
#   "institutional": {
#     "Holder": {
#       "0": "Vanguard Group, Inc. (The)",
#       "1": "Blackrock Inc.",
#       "2": "State Street Corporation",
#       "3": "Geode Capital Management, LLC",
#       "4": "Charles Schwab Investment Management, Inc.",
#       "5": "Northern Trust Corporation",
#       "6": "Morgan Stanley",
#       "7": "Bank Of New York Mellon Corporation",
#       "8": "Norges Bank Investment Management",
#       "9": "Bank of America Corporation"
#     },
#     "Shares": {
#       "0": 73806391,
#       "1": 62271273,
#       "2": 51941856,
#       "3": 13310817,
#       "4": 12571878,
#       "5": 10652880,
#       "6": 9853901,
#       "7": 9628160,
#       "8": 8865649,
#       "9": 8074146
#     },
#     "Date Reported": {
#       "0": "Dec 30, 2020",
#       "1": "Dec 30, 2020",
#       "2": "Dec 30, 2020",
#       "3": "Dec 30, 2020",
#       "4": "Dec 30, 2020",
#       "5": "Dec 30, 2020",
#       "6": "Dec 30, 2020",
#       "7": "Dec 30, 2020",
#       "8": "Dec 30, 2020",
#       "9": "Dec 30, 2020"
#     },
#     "% Out": {
#       "0": "8.26%",
#       "1": "6.97%",
#       "2": "5.81%",
#       "3": "1.49%",
#       "4": "1.41%",
#       "5": "1.19%",
#       "6": "1.10%",
#       "7": "1.08%",
#       "8": "0.99%",
#       "9": "0.90%"
#     },
#     "Value": {
#       "0": 9290748499,
#       "1": 7838707845,
#       "2": 6538440833,
#       "3": 1675565643,
#       "4": 1582548002,
#       "5": 1340984534,
#       "6": 1240409057,
#       "7": 1211992780,
#       "8": 1116007896,
#       "9": 1016373498
#     }
#   },
#   "mutualfund": {
#     "Holder": {
#       "0": "Vanguard Total Stock Market Index Fund",
#       "1": "Vanguard 500 Index Fund",
#       "2": "SPDR S&P 500 ETF Trust",
#       "3": "Fidelity 500 Index Fund",
#       "4": "Vanguard Institutional Index Fund-Institutional Index Fund",
#       "5": "iShares Core S&P 500 ETF",
#       "6": "Vanguard Index-Value Index Fund",
#       "7": "SPDR Dow Jones Industrial Average ETF",
#       "8": "Franklin Custodian Funds-Income Fund",
#       "9": "Schwab Strategic Tr-Schwab U.S. Dividend Equity ETF"
#     },
#     "Shares": {
#       "0": 25108610,
#       "1": 17854830,
#       "2": 9085980,
#       "3": 8074523,
#       "4": 7327901,
#       "5": 6866860,
#       "6": 5998301,
#       "7": 5493768,
#       "8": 4487000,
#       "9": 4463676
#     },
#     "Date Reported": {
#       "0": "Dec 30, 2020",
#       "1": "Dec 30, 2020",
#       "2": "Feb 27, 2021",
#       "3": "Jan 30, 2021",
#       "4": "Dec 30, 2020",
#       "5": "Feb 27, 2021",
#       "6": "Dec 30, 2020",
#       "7": "Feb 27, 2021",
#       "8": "Dec 30, 2020",
#       "9": "Nov 29, 2020"
#     },
#     "% Out": {
#       "0": "2.81%",
#       "1": "2.00%",
#       "2": "1.02%",
#       "3": "0.90%",
#       "4": "0.82%",
#       "5": "0.77%",
#       "6": "0.67%",
#       "7": "0.61%",
#       "8": "0.50%",
#       "9": "0.50%"
#     },
#     "Value": {
#       "0": 3160671826,
#       "1": 2247566000,
#       "2": 1080595601,
#       "3": 961756434,
#       "4": 922436177,
#       "5": 816675659,
#       "6": 755066129,
#       "7": 653373828,
#       "8": 564823560,
#       "9": 551353259
#     }
#   }
# }

# %% [markdown]
# ## holders endpoint: the yfinance compatible Holders request
#
# The `compat.yfinance` module offers a `Holders request` that is compatible with `yfinance`. It is derived from the `yahoo.Holders` class, but it offers properties to access the information sections of the Holders data.

# %%
import virtual_finance_api.compat.yfinance.endpoints as yf

# %%
r = yf.Holders(ticker)

# %%
print(json.dumps(client.request(r), indent=2))
# Out:
# {
#   "major": {
#     "0": {
#       "0": "0.13%",
#       "1": "58.58%",
#       "2": "58.66%",
#       "3": "2561"
#     },
#     "1": {
#       "0": "% of Shares Held by All Insider",
#       "1": "% of Shares Held by Institutions",
#       "2": "% of Float Held by Institutions",
#       "3": "Number of Institutions Holding Shares"
#     }
#   },
#   "institutional": {
#     "Holder": {
#       "0": "Vanguard Group, Inc. (The)",
#       "1": "Blackrock Inc.",
#       "2": "State Street Corporation",
#       "3": "Geode Capital Management, LLC",
#       "4": "Charles Schwab Investment Management, Inc.",
#       "5": "Northern Trust Corporation",
#       "6": "Morgan Stanley",
#       "7": "Bank Of New York Mellon Corporation",
#       "8": "Norges Bank Investment Management",
#       "9": "Bank of America Corporation"
#     },
#     "Shares": {
#       "0": 73806391,
#       "1": 62271273,
#       "2": 51941856,
#       "3": 13310817,
#       "4": 12571878,
#       "5": 10652880,
#       "6": 9853901,
#       "7": 9628160,
#       "8": 8865649,
#       "9": 8074146
#     },
#     "Date Reported": {
#       "0": "Dec 30, 2020",
#       "1": "Dec 30, 2020",
#       "2": "Dec 30, 2020",
#       "3": "Dec 30, 2020",
#       "4": "Dec 30, 2020",
#       "5": "Dec 30, 2020",
#       "6": "Dec 30, 2020",
#       "7": "Dec 30, 2020",
#       "8": "Dec 30, 2020",
#       "9": "Dec 30, 2020"
#     },
#     "% Out": {
#       "0": "8.26%",
#       "1": "6.97%",
#       "2": "5.81%",
#       "3": "1.49%",
#       "4": "1.41%",
#       "5": "1.19%",
#       "6": "1.10%",
#       "7": "1.08%",
#       "8": "0.99%",
#       "9": "0.90%"
#     },
#     "Value": {
#       "0": 9290748499,
#       "1": 7838707845,
#       "2": 6538440833,
#       "3": 1675565643,
#       "4": 1582548002,
#       "5": 1340984534,
#       "6": 1240409057,
#       "7": 1211992780,
#       "8": 1116007896,
#       "9": 1016373498
#     }
#   },
#   "mutualfund": {
#     "Holder": {
#       "0": "Vanguard Total Stock Market Index Fund",
#       "1": "Vanguard 500 Index Fund",
#       "2": "SPDR S&P 500 ETF Trust",
#       "3": "Fidelity 500 Index Fund",
#       "4": "Vanguard Institutional Index Fund-Institutional Index Fund",
#       "5": "iShares Core S&P 500 ETF",
#       "6": "Vanguard Index-Value Index Fund",
#       "7": "SPDR Dow Jones Industrial Average ETF",
#       "8": "Franklin Custodian Funds-Income Fund",
#       "9": "Schwab Strategic Tr-Schwab U.S. Dividend Equity ETF"
#     },
#     "Shares": {
#       "0": 25108610,
#       "1": 17854830,
#       "2": 9085980,
#       "3": 8074523,
#       "4": 7327901,
#       "5": 6866860,
#       "6": 5998301,
#       "7": 5493768,
#       "8": 4487000,
#       "9": 4463676
#     },
#     "Date Reported": {
#       "0": "Dec 30, 2020",
#       "1": "Dec 30, 2020",
#       "2": "Feb 27, 2021",
#       "3": "Jan 30, 2021",
#       "4": "Dec 30, 2020",
#       "5": "Feb 27, 2021",
#       "6": "Dec 30, 2020",
#       "7": "Feb 27, 2021",
#       "8": "Dec 30, 2020",
#       "9": "Nov 29, 2020"
#     },
#     "% Out": {
#       "0": "2.81%",
#       "1": "2.00%",
#       "2": "1.02%",
#       "3": "0.90%",
#       "4": "0.82%",
#       "5": "0.77%",
#       "6": "0.67%",
#       "7": "0.61%",
#       "8": "0.50%",
#       "9": "0.50%"
#     },
#     "Value": {
#       "0": 3160671826,
#       "1": 2247566000,
#       "2": 1080595601,
#       "3": 961756434,
#       "4": 922436177,
#       "5": 816675659,
#       "6": 755066129,
#       "7": 653373828,
#       "8": 564823560,
#       "9": 551353259
#     }
#   }
# }

# %%
display(r.major)
# Out:
#         0                                      1
# 0   0.13%        % of Shares Held by All Insider
# 1  58.58%       % of Shares Held by Institutions
# 2  58.66%        % of Float Held by Institutions
# 3    2561  Number of Institutions Holding Shares

# %%
display(r.mutualfund)
# Out:
#                                               Holder    Shares Date Reported  \
# 0             Vanguard Total Stock Market Index Fund  25108610    2020-12-30
# 1                            Vanguard 500 Index Fund  17854830    2020-12-30
# 2                             SPDR S&P 500 ETF Trust   9085980    2021-02-27
# 3                            Fidelity 500 Index Fund   8074523    2021-01-30
# 4  Vanguard Institutional Index Fund-Institutiona...   7327901    2020-12-30
# 5                           iShares Core S&P 500 ETF   6866860    2021-02-27
# 6                    Vanguard Index-Value Index Fund   5998301    2020-12-30
# 7              SPDR Dow Jones Industrial Average ETF   5493768    2021-02-27
# 8               Franklin Custodian Funds-Income Fund   4487000    2020-12-30
# 9  Schwab Strategic Tr-Schwab U.S. Dividend Equit...   4463676    2020-11-29
#
#     % Out       Value
# 0  0.0281  3160671826
# 1  0.0200  2247566000
# 2  0.0102  1080595601
# 3  0.0090   961756434
# 4  0.0082   922436177
# 5  0.0077   816675659
# 6  0.0067   755066129
# 7  0.0061   653373828
# 8  0.0050   564823560
# 9  0.0050   551353259

# %%
display(r.institutional)
# Out:
#                                        Holder    Shares Date Reported   % Out  \
# 0                  Vanguard Group, Inc. (The)  73806391    2020-12-30  0.0826
# 1                              Blackrock Inc.  62271273    2020-12-30  0.0697
# 2                    State Street Corporation  51941856    2020-12-30  0.0581
# 3               Geode Capital Management, LLC  13310817    2020-12-30  0.0149
# 4  Charles Schwab Investment Management, Inc.  12571878    2020-12-30  0.0141
# 5                  Northern Trust Corporation  10652880    2020-12-30  0.0119
# 6                              Morgan Stanley   9853901    2020-12-30  0.0110
# 7         Bank Of New York Mellon Corporation   9628160    2020-12-30  0.0108
# 8           Norges Bank Investment Management   8865649    2020-12-30  0.0099
# 9                 Bank of America Corporation   8074146    2020-12-30  0.0090
#
#         Value
# 0  9290748499
# 1  7838707845
# 2  6538440833
# 3  1675565643
# 4  1582548002
# 5  1340984534
# 6  1240409057
# 7  1211992780
# 8  1116007896
# 9  1016373498

# %% [markdown]
# [index](./index.ipynb) | [yhoo-profile](./profile.ipynb) | [yhoo-financials](./financials.ipynb) | [yhoo-holders](./holders.ipynb) | [yhoo-options](./options.ipynb) | [yhoo-history](./history.ipynb)
