# %% [markdown]
# [index](./index.ipynb) | [yhoo-profile](./profile.ipynb) | [yhoo-financials](./financials.ipynb) | [yhoo-holders](./holders.ipynb) | [yhoo-options](./options.ipynb) | [yhoo-history](./history.ipynb)

# %% [markdown]
# # Virtual finance API
#
#
# The Yahoo.finance.com `options` data.

# %%
import virtual_finance_api as fa
import virtual_finance_api.endpoints.yahoo as yh
import json

# %% [markdown]
# ## Logging
#
# Optionally setup the logging. The standard logging levels apply: DEBUG, INFO, WARNING, ERROR, CRITICAL

# %%
import logging

logging.basicConfig(
    filename="/tmp/virtual_finance_api.log",
    level=logging.INFO,
    format='%(asctime)s [%(levelname)s] %(name)s : %(message)s',
)

# %% [raw]
# from IPython.core.display import display, HTML
#
# display(HTML("<style>.container { width:100% !important; }</style>"))

# %% [markdown]
# ## The client processing the requests ...

# %%
client = fa.Client()

# %%
ticker = 'IBM'

# %% [markdown]
# ## options endpoint : the Options request

# %%
r = yh.Options(ticker)

# %%
rv = client.request(r)

# %%
print(json.dumps(rv, indent=2))
# Out:
# {
#   "optionChain": {
#     "result": [
#       {
#         "underlyingSymbol": "IBM",
#         "expirationDates": [
#           1617235200,
#           1617926400,
#           1618531200,
#           1619136000,
#           1619740800,
#           1620345600,
#           1621555200,
#           1623974400,
#           1626393600,
#           1631836800,
#           1634256000,
#           1642723200,
#           1674172800
#         ],
#         "strikes": [
#           65.0,
#           75.0,
#           90.0,
#           100.0,
#           105.0,
#           108.0,
#           109.0,
#           110.0,
#           111.0,
#           112.0,
#           113.0,
#           114.0,
#           115.0,
#           116.0,
#           117.0,
#           118.0,
#           119.0,
#           120.0,
#           121.0,
#           122.0,
#           123.0,
#           124.0,
#           125.0,
#           126.0,
#           127.0,
#           128.0,
#           129.0,
#           130.0,
#           131.0,
#           132.0,
#           133.0,
#           134.0,
#           135.0,
#           136.0,
#           137.0,
#           138.0,
#           139.0,
#           140.0,
#           141.0,
#           142.0,
#           143.0,
#           145.0,
#           150.0
#         ],
#         "hasMiniOptions": false,
#         "quote": {
#           "language": "en-US",
#           "region": "US",
#           "quoteType": "EQUITY",
#           "quoteSourceName": "Nasdaq Real Time Price",
#           "triggerable": true,
#           "currency": "USD",
#           "exchange": "NYQ",
#           "shortName": "International Business Machines",
#           "longName": "International Business Machines Corporation",
#           "messageBoardId": "finmb_112350",
#           "exchangeTimezoneName": "America/New_York",
#           "exchangeTimezoneShortName": "EDT",
#           "gmtOffSetMilliseconds": -14400000,
#           "market": "us_market",
#           "esgPopulated": false,
#           "regularMarketChange": -0.23001099,
#           "regularMarketChangePercent": -0.16865447,
#           "regularMarketTime": 1617032717,
#           "regularMarketPrice": 136.15,
#           "regularMarketDayHigh": 137.05,
#           "regularMarketDayRange": "135.57 - 137.05",
#           "regularMarketDayLow": 135.57,
#           "regularMarketVolume": 1625668,
#           "regularMarketPreviousClose": 136.38,
#           "bid": 135.97,
#           "ask": 136.08,
#           "bidSize": 9,
#           "askSize": 14,
#           "fullExchangeName": "NYSE",
#           "financialCurrency": "USD",
#           "regularMarketOpen": 135.98,
#           "averageDailyVolume3Month": 6668222,
#           "averageDailyVolume10Day": 5578900,
#           "fiftyTwoWeekLowChange": 31.629997,
#           "fiftyTwoWeekLowChangePercent": 0.30262148,
#           "fiftyTwoWeekRange": "104.52 - 137.05",
#           "fiftyTwoWeekHighChange": -0.90000916,
#           "fiftyTwoWeekHighChangePercent": -0.006567013,
#           "fiftyTwoWeekLow": 104.52,
#           "fiftyTwoWeekHigh": 137.05,
#           "dividendDate": 1615334400,
#           "earningsTimestamp": 1618862400,
#           "earningsTimestampStart": 1618862400,
#           "earningsTimestampEnd": 1618862400,
#           "trailingAnnualDividendRate": 6.51,
#           "trailingPE": 21.843414,
#           "trailingAnnualDividendYield": 0.04773427,
#           "epsTrailingTwelveMonths": 6.233,
#           "epsForward": 12.08,
#           "epsCurrentYear": 11.02,
#           "priceEpsCurrentYear": 12.354809,
#           "sharesOutstanding": 893593984,
#           "bookValue": 23.074,
#           "fiftyDayAverage": 124.69029,
#           "fiftyDayAverageChange": 11.459702,
#           "fiftyDayAverageChangePercent": 0.091905326,
#           "marketState": "REGULAR",
#           "twoHundredDayAverage": 122.54584,
#           "twoHundredDayAverageChange": 13.6041565,
#           "twoHundredDayAverageChangePercent": 0.1110128,
#           "marketCap": 121662816256,
#           "forwardPE": 11.270695,
#           "priceToBook": 5.9005804,
#           "sourceInterval": 15,
#           "exchangeDataDelayedBy": 0,
#           "firstTradeDateMilliseconds": -252322200000,
#           "priceHint": 2,
#           "tradeable": false,
#           "displayName": "IBM",
#           "symbol": "IBM"
#         },
#         "options": [
#           {
#             "expirationDate": 1617235200,
#             "hasMiniOptions": false,
#             "calls": [
#               {
#                 "contractSymbol": "IBM210401C00065000",
#                 "strike": 65.0,
#                 "currency": "USD",
#                 "lastPrice": 65.15,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 3,
#                 "openInterest": 4,
#                 "bid": 70.65,
#                 "ask": 71.05,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616175458,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00075000",
#                 "strike": 75.0,
#                 "currency": "USD",
#                 "lastPrice": 55.35,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 10,
#                 "openInterest": 10,
#                 "bid": 60.75,
#                 "ask": 61.05,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616176170,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00090000",
#                 "strike": 90.0,
#                 "currency": "USD",
#                 "lastPrice": 40.4,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 13,
#                 "openInterest": 13,
#                 "bid": 45.7,
#                 "ask": 46.05,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616176710,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00100000",
#                 "strike": 100.0,
#                 "currency": "USD",
#                 "lastPrice": 31.1,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 3,
#                 "openInterest": 17,
#                 "bid": 35.65,
#                 "ask": 36.1,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616183550,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00108000",
#                 "strike": 108.0,
#                 "currency": "USD",
#                 "lastPrice": 24.1,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 1,
#                 "openInterest": 4,
#                 "bid": 27.6,
#                 "ask": 28.0,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616595259,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00110000",
#                 "strike": 110.0,
#                 "currency": "USD",
#                 "lastPrice": 22.62,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 2,
#                 "openInterest": 11,
#                 "bid": 25.7,
#                 "ask": 26.05,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616691939,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00111000",
#                 "strike": 111.0,
#                 "currency": "USD",
#                 "lastPrice": 20.75,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 1,
#                 "openInterest": 2,
#                 "bid": 24.7,
#                 "ask": 24.95,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616594456,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00112000",
#                 "strike": 112.0,
#                 "currency": "USD",
#                 "lastPrice": 18.3,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 13,
#                 "openInterest": 32,
#                 "bid": 23.6,
#                 "ask": 23.95,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616174503,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00114000",
#                 "strike": 114.0,
#                 "currency": "USD",
#                 "lastPrice": 18.75,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 2,
#                 "openInterest": 1,
#                 "bid": 21.55,
#                 "ask": 21.95,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616692283,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00115000",
#                 "strike": 115.0,
#                 "currency": "USD",
#                 "lastPrice": 20.8,
#                 "change": 4.449999,
#                 "percentChange": 27.217117,
#                 "volume": 2,
#                 "openInterest": 24,
#                 "bid": 20.7,
#                 "ask": 21.05,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616429503,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00116000",
#                 "strike": 116.0,
#                 "currency": "USD",
#                 "lastPrice": 19.06,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 1,
#                 "openInterest": 4,
#                 "bid": 19.75,
#                 "ask": 20.05,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616780284,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00117000",
#                 "strike": 117.0,
#                 "currency": "USD",
#                 "lastPrice": 14.76,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 1,
#                 "openInterest": 4,
#                 "bid": 18.8,
#                 "ask": 19.0,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616593554,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00118000",
#                 "strike": 118.0,
#                 "currency": "USD",
#                 "lastPrice": 18.0,
#                 "change": 4.8500004,
#                 "percentChange": 36.882133,
#                 "volume": 3,
#                 "openInterest": 18,
#                 "bid": 17.75,
#                 "ask": 18.15,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617029975,
#                 "impliedVolatility": 0.2500075,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00119000",
#                 "strike": 119.0,
#                 "currency": "USD",
#                 "lastPrice": 17.21,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 5,
#                 "openInterest": 49,
#                 "bid": 16.7,
#                 "ask": 17.0,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616788616,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00120000",
#                 "strike": 120.0,
#                 "currency": "USD",
#                 "lastPrice": 14.97,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 2,
#                 "openInterest": 37,
#                 "bid": 15.7,
#                 "ask": 16.0,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616778874,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00121000",
#                 "strike": 121.0,
#                 "currency": "USD",
#                 "lastPrice": 10.39,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 10,
#                 "openInterest": 110,
#                 "bid": 14.65,
#                 "ask": 15.0,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616607298,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00122000",
#                 "strike": 122.0,
#                 "currency": "USD",
#                 "lastPrice": 11.95,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 8,
#                 "openInterest": 151,
#                 "bid": 13.75,
#                 "ask": 14.05,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616767536,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00123000",
#                 "strike": 123.0,
#                 "currency": "USD",
#                 "lastPrice": 12.0,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 40,
#                 "openInterest": 152,
#                 "bid": 12.65,
#                 "ask": 13.0,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616782165,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00124000",
#                 "strike": 124.0,
#                 "currency": "USD",
#                 "lastPrice": 12.19,
#                 "change": 2.1699991,
#                 "percentChange": 21.656677,
#                 "volume": 12,
#                 "openInterest": 239,
#                 "bid": 11.8,
#                 "ask": 12.1,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617030316,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00125000",
#                 "strike": 125.0,
#                 "currency": "USD",
#                 "lastPrice": 11.45,
#                 "change": 0.5799999,
#                 "percentChange": 5.335786,
#                 "volume": 2,
#                 "openInterest": 334,
#                 "bid": 10.7,
#                 "ask": 11.0,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617028298,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00126000",
#                 "strike": 126.0,
#                 "currency": "USD",
#                 "lastPrice": 10.95,
#                 "change": 1.96,
#                 "percentChange": 21.802002,
#                 "volume": 4,
#                 "openInterest": 165,
#                 "bid": 9.75,
#                 "ask": 10.1,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616782796,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00127000",
#                 "strike": 127.0,
#                 "currency": "USD",
#                 "lastPrice": 7.94,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 17,
#                 "openInterest": 146,
#                 "bid": 8.8,
#                 "ask": 9.1,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616781114,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00128000",
#                 "strike": 128.0,
#                 "currency": "USD",
#                 "lastPrice": 7.86,
#                 "change": -0.5399995,
#                 "percentChange": -6.4285655,
#                 "volume": 4,
#                 "openInterest": 363,
#                 "bid": 7.8,
#                 "ask": 8.1,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617030827,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00129000",
#                 "strike": 129.0,
#                 "currency": "USD",
#                 "lastPrice": 7.09,
#                 "change": 0.19000006,
#                 "percentChange": 2.753624,
#                 "volume": 27,
#                 "openInterest": 409,
#                 "bid": 6.85,
#                 "ask": 7.1,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617030578,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00130000",
#                 "strike": 130.0,
#                 "currency": "USD",
#                 "lastPrice": 5.99,
#                 "change": -0.31000042,
#                 "percentChange": -4.9206414,
#                 "volume": 47,
#                 "openInterest": 1976,
#                 "bid": 5.9,
#                 "ask": 6.0,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617031073,
#                 "impliedVolatility": 1.0000000000000003e-05,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00131000",
#                 "strike": 131.0,
#                 "currency": "USD",
#                 "lastPrice": 5.01,
#                 "change": -0.089999676,
#                 "percentChange": -1.7646996,
#                 "volume": 11,
#                 "openInterest": 466,
#                 "bid": 4.95,
#                 "ask": 5.25,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617031199,
#                 "impliedVolatility": 0.245124736328125,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00132000",
#                 "strike": 132.0,
#                 "currency": "USD",
#                 "lastPrice": 4.5,
#                 "change": 0.3800001,
#                 "percentChange": 9.223304,
#                 "volume": 39,
#                 "openInterest": 748,
#                 "bid": 4.0,
#                 "ask": 4.25,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617029625,
#                 "impliedVolatility": 0.20703917968749996,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00133000",
#                 "strike": 133.0,
#                 "currency": "USD",
#                 "lastPrice": 3.46,
#                 "change": 0.22000003,
#                 "percentChange": 6.7901244,
#                 "volume": 19,
#                 "openInterest": 275,
#                 "bid": 3.05,
#                 "ask": 3.35,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617026963,
#                 "impliedVolatility": 0.20410952148437497,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00134000",
#                 "strike": 134.0,
#                 "currency": "USD",
#                 "lastPrice": 2.35,
#                 "change": -0.58000016,
#                 "percentChange": -19.795227,
#                 "volume": 81,
#                 "openInterest": 381,
#                 "bid": 2.22,
#                 "ask": 2.53,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617030807,
#                 "impliedVolatility": 0.2036212451171875,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00135000",
#                 "strike": 135.0,
#                 "currency": "USD",
#                 "lastPrice": 1.7,
#                 "change": -0.51,
#                 "percentChange": -23.076921,
#                 "volume": 98,
#                 "openInterest": 711,
#                 "bid": 1.62,
#                 "ask": 1.75,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617031770,
#                 "impliedVolatility": 0.19043778320312502,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00136000",
#                 "strike": 136.0,
#                 "currency": "USD",
#                 "lastPrice": 1.1,
#                 "change": -0.39999998,
#                 "percentChange": -26.666664,
#                 "volume": 184,
#                 "openInterest": 483,
#                 "bid": 1.01,
#                 "ask": 1.14,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617031750,
#                 "impliedVolatility": 0.1870198486328125,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401C00137000",
#                 "strike": 137.0,
#                 "currency": "USD",
#                 "lastPrice": 0.67,
#                 "change": -0.27999997,
#                 "percentChange": -29.47368,
#                 "volume": 585,
#                 "openInterest": 619,
#                 "bid": 0.68,
#                 "ask": 0.75,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617031674,
#                 "impliedVolatility": 0.19727365234375,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401C00138000",
#                 "strike": 138.0,
#                 "currency": "USD",
#                 "lastPrice": 0.41,
#                 "change": -0.29999998,
#                 "percentChange": -42.25352,
#                 "volume": 451,
#                 "openInterest": 881,
#                 "bid": 0.4,
#                 "ask": 0.44,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617030565,
#                 "impliedVolatility": 0.1977619287109375,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401C00139000",
#                 "strike": 139.0,
#                 "currency": "USD",
#                 "lastPrice": 0.27,
#                 "change": -0.119999975,
#                 "percentChange": -30.769224,
#                 "volume": 90,
#                 "openInterest": 107,
#                 "bid": 0.25,
#                 "ask": 0.29,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617028474,
#                 "impliedVolatility": 0.2124102197265625,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401C00140000",
#                 "strike": 140.0,
#                 "currency": "USD",
#                 "lastPrice": 0.16,
#                 "change": -0.13,
#                 "percentChange": -44.827587,
#                 "volume": 499,
#                 "openInterest": 705,
#                 "bid": 0.17,
#                 "ask": 0.19,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617031365,
#                 "impliedVolatility": 0.225593681640625,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401C00141000",
#                 "strike": 141.0,
#                 "currency": "USD",
#                 "lastPrice": 0.17,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 72,
#                 "openInterest": 110,
#                 "bid": 0.12,
#                 "ask": 0.14,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617027286,
#                 "impliedVolatility": 0.24463645996093752,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401C00142000",
#                 "strike": 142.0,
#                 "currency": "USD",
#                 "lastPrice": 0.14,
#                 "change": 0.049999997,
#                 "percentChange": 55.55555,
#                 "volume": 21,
#                 "openInterest": 3,
#                 "bid": 0.09,
#                 "ask": 0.11,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617024601,
#                 "impliedVolatility": 0.26563234375,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401C00143000",
#                 "strike": 143.0,
#                 "currency": "USD",
#                 "lastPrice": 0.09,
#                 "change": -0.009999998,
#                 "percentChange": -9.999997,
#                 "volume": 131,
#                 "openInterest": 3,
#                 "bid": 0.07,
#                 "ask": 0.09,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617031151,
#                 "impliedVolatility": 0.28711650390624993,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401C00145000",
#                 "strike": 145.0,
#                 "currency": "USD",
#                 "lastPrice": 0.05,
#                 "change": -0.029999997,
#                 "percentChange": -37.499996,
#                 "volume": 34,
#                 "openInterest": 202,
#                 "bid": 0.05,
#                 "ask": 0.06,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617031063,
#                 "impliedVolatility": 0.3242255078124999,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401C00150000",
#                 "strike": 150.0,
#                 "currency": "USD",
#                 "lastPrice": 0.02,
#                 "change": -0.01,
#                 "percentChange": -33.333336,
#                 "volume": 10,
#                 "openInterest": 5,
#                 "bid": 0.02,
#                 "ask": 0.04,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617029755,
#                 "impliedVolatility": 0.437505625,
#                 "inTheMoney": false
#               }
#             ],
#             "puts": [
#               {
#                 "contractSymbol": "IBM210401P00100000",
#                 "strike": 100.0,
#                 "currency": "USD",
#                 "lastPrice": 0.05,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 1,
#                 "openInterest": 96,
#                 "bid": 0.0,
#                 "ask": 0.02,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616170620,
#                 "impliedVolatility": 1.0625046875000002,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00105000",
#                 "strike": 105.0,
#                 "currency": "USD",
#                 "lastPrice": 0.01,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 2,
#                 "openInterest": 503,
#                 "bid": 0.01,
#                 "ask": 0.03,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617024811,
#                 "impliedVolatility": 0.9687503125,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00108000",
#                 "strike": 108.0,
#                 "currency": "USD",
#                 "lastPrice": 0.03,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 1,
#                 "openInterest": 207,
#                 "bid": 0.0,
#                 "ask": 0.03,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616767798,
#                 "impliedVolatility": 0.8437515624999999,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00109000",
#                 "strike": 109.0,
#                 "currency": "USD",
#                 "lastPrice": 0.02,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 8,
#                 "openInterest": 34,
#                 "bid": 0.0,
#                 "ask": 0.03,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616767981,
#                 "impliedVolatility": 0.8125018749999999,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00110000",
#                 "strike": 110.0,
#                 "currency": "USD",
#                 "lastPrice": 0.01,
#                 "change": -0.01,
#                 "percentChange": -50.0,
#                 "volume": 1,
#                 "openInterest": 151,
#                 "bid": 0.01,
#                 "ask": 0.03,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616778446,
#                 "impliedVolatility": 0.8125018749999999,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00111000",
#                 "strike": 111.0,
#                 "currency": "USD",
#                 "lastPrice": 0.02,
#                 "change": -0.01,
#                 "percentChange": -33.333336,
#                 "volume": 30,
#                 "openInterest": 256,
#                 "bid": 0.0,
#                 "ask": 0.04,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617028720,
#                 "impliedVolatility": 0.7812521875,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00112000",
#                 "strike": 112.0,
#                 "currency": "USD",
#                 "lastPrice": 0.07,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 166,
#                 "openInterest": 234,
#                 "bid": 0.0,
#                 "ask": 0.04,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616688130,
#                 "impliedVolatility": 0.7500025,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00113000",
#                 "strike": 113.0,
#                 "currency": "USD",
#                 "lastPrice": 0.02,
#                 "change": -0.030000001,
#                 "percentChange": -60.000004,
#                 "volume": 1,
#                 "openInterest": 57,
#                 "bid": 0.0,
#                 "ask": 0.05,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616680421,
#                 "impliedVolatility": 0.73437765625,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00114000",
#                 "strike": 114.0,
#                 "currency": "USD",
#                 "lastPrice": 0.06,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 6,
#                 "openInterest": 28,
#                 "bid": 0.0,
#                 "ask": 0.05,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616699103,
#                 "impliedVolatility": 0.70312796875,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00115000",
#                 "strike": 115.0,
#                 "currency": "USD",
#                 "lastPrice": 0.03,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 1,
#                 "openInterest": 79,
#                 "bid": 0.0,
#                 "ask": 0.05,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616783878,
#                 "impliedVolatility": 0.6757844921875001,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00116000",
#                 "strike": 116.0,
#                 "currency": "USD",
#                 "lastPrice": 0.01,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 3,
#                 "openInterest": 2315,
#                 "bid": 0.0,
#                 "ask": 0.02,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616786787,
#                 "impliedVolatility": 0.57812921875,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00117000",
#                 "strike": 117.0,
#                 "currency": "USD",
#                 "lastPrice": 0.06,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 20,
#                 "openInterest": 98,
#                 "bid": 0.0,
#                 "ask": 0.06,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616610604,
#                 "impliedVolatility": 0.6289099609375001,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00118000",
#                 "strike": 118.0,
#                 "currency": "USD",
#                 "lastPrice": 0.03,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 5,
#                 "openInterest": 127,
#                 "bid": 0.0,
#                 "ask": 0.04,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616786787,
#                 "impliedVolatility": 0.570316796875,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00119000",
#                 "strike": 119.0,
#                 "currency": "USD",
#                 "lastPrice": 0.03,
#                 "change": -0.08,
#                 "percentChange": -72.72727,
#                 "volume": 10,
#                 "openInterest": 167,
#                 "bid": 0.01,
#                 "ask": 0.03,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617028583,
#                 "impliedVolatility": 0.5390671093750001,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00120000",
#                 "strike": 120.0,
#                 "currency": "USD",
#                 "lastPrice": 0.04,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 6,
#                 "openInterest": 137,
#                 "bid": 0.01,
#                 "ask": 0.07,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616787756,
#                 "impliedVolatility": 0.5585981640625001,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00121000",
#                 "strike": 121.0,
#                 "currency": "USD",
#                 "lastPrice": 0.02,
#                 "change": -0.030000001,
#                 "percentChange": -60.000004,
#                 "volume": 5,
#                 "openInterest": 61,
#                 "bid": 0.02,
#                 "ask": 0.04,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617029483,
#                 "impliedVolatility": 0.5039112109375,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00122000",
#                 "strike": 122.0,
#                 "currency": "USD",
#                 "lastPrice": 0.03,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 10,
#                 "openInterest": 948,
#                 "bid": 0.02,
#                 "ask": 0.05,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616788251,
#                 "impliedVolatility": 0.5097705273437501,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00123000",
#                 "strike": 123.0,
#                 "currency": "USD",
#                 "lastPrice": 0.05,
#                 "change": -0.02,
#                 "percentChange": -28.571428,
#                 "volume": 2,
#                 "openInterest": 131,
#                 "bid": 0.03,
#                 "ask": 0.04,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616788572,
#                 "impliedVolatility": 0.46094289062500005,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00124000",
#                 "strike": 124.0,
#                 "currency": "USD",
#                 "lastPrice": 0.03,
#                 "change": -0.03,
#                 "percentChange": -50.0,
#                 "volume": 7,
#                 "openInterest": 484,
#                 "bid": 0.03,
#                 "ask": 0.06,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617029545,
#                 "impliedVolatility": 0.45703667968750006,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00125000",
#                 "strike": 125.0,
#                 "currency": "USD",
#                 "lastPrice": 0.04,
#                 "change": -0.030000001,
#                 "percentChange": -42.857143,
#                 "volume": 42,
#                 "openInterest": 155,
#                 "bid": 0.04,
#                 "ask": 0.06,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617030314,
#                 "impliedVolatility": 0.42383388671875,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00126000",
#                 "strike": 126.0,
#                 "currency": "USD",
#                 "lastPrice": 0.05,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "volume": 25,
#                 "openInterest": 8401,
#                 "bid": 0.04,
#                 "ask": 0.06,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617025469,
#                 "impliedVolatility": 0.39063109375,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00127000",
#                 "strike": 127.0,
#                 "currency": "USD",
#                 "lastPrice": 0.07,
#                 "change": -0.04,
#                 "percentChange": -36.363636,
#                 "volume": 7,
#                 "openInterest": 137,
#                 "bid": 0.06,
#                 "ask": 0.08,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617024954,
#                 "impliedVolatility": 0.37500625,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00128000",
#                 "strike": 128.0,
#                 "currency": "USD",
#                 "lastPrice": 0.09,
#                 "change": -0.019999996,
#                 "percentChange": -18.181814,
#                 "volume": 20,
#                 "openInterest": 274,
#                 "bid": 0.07,
#                 "ask": 0.1,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617028217,
#                 "impliedVolatility": 0.35547519531249994,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00129000",
#                 "strike": 129.0,
#                 "currency": "USD",
#                 "lastPrice": 0.1,
#                 "change": -0.04,
#                 "percentChange": -28.571428,
#                 "volume": 31,
#                 "openInterest": 8450,
#                 "bid": 0.1,
#                 "ask": 0.12,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617030437,
#                 "impliedVolatility": 0.3320379296875,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00130000",
#                 "strike": 130.0,
#                 "currency": "USD",
#                 "lastPrice": 0.12,
#                 "change": -0.04,
#                 "percentChange": -25.0,
#                 "volume": 70,
#                 "openInterest": 528,
#                 "bid": 0.13,
#                 "ask": 0.14,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617028816,
#                 "impliedVolatility": 0.304694453125,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00131000",
#                 "strike": 131.0,
#                 "currency": "USD",
#                 "lastPrice": 0.16,
#                 "change": -0.09,
#                 "percentChange": -36.0,
#                 "volume": 35,
#                 "openInterest": 353,
#                 "bid": 0.17,
#                 "ask": 0.18,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617027530,
#                 "impliedVolatility": 0.28321029296874994,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00132000",
#                 "strike": 132.0,
#                 "currency": "USD",
#                 "lastPrice": 0.24,
#                 "change": -0.060000017,
#                 "percentChange": -20.000006,
#                 "volume": 260,
#                 "openInterest": 333,
#                 "bid": 0.22,
#                 "ask": 0.27,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617030777,
#                 "impliedVolatility": 0.27246821289062495,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00133000",
#                 "strike": 133.0,
#                 "currency": "USD",
#                 "lastPrice": 0.39,
#                 "change": -0.01000002,
#                 "percentChange": -2.500005,
#                 "volume": 126,
#                 "openInterest": 228,
#                 "bid": 0.32,
#                 "ask": 0.36,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617031368,
#                 "impliedVolatility": 0.25098405273437496,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00134000",
#                 "strike": 134.0,
#                 "currency": "USD",
#                 "lastPrice": 0.54,
#                 "change": -0.00999999,
#                 "percentChange": -1.8181801,
#                 "volume": 143,
#                 "openInterest": 207,
#                 "bid": 0.48,
#                 "ask": 0.54,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617031366,
#                 "impliedVolatility": 0.23975369628906246,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00135000",
#                 "strike": 135.0,
#                 "currency": "USD",
#                 "lastPrice": 0.8,
#                 "change": -0.029999971,
#                 "percentChange": -3.6144545,
#                 "volume": 276,
#                 "openInterest": 93,
#                 "bid": 0.75,
#                 "ask": 0.85,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617030835,
#                 "impliedVolatility": 0.23804472900390622,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00136000",
#                 "strike": 136.0,
#                 "currency": "USD",
#                 "lastPrice": 1.26,
#                 "change": 0.03999996,
#                 "percentChange": 3.2786853,
#                 "volume": 403,
#                 "openInterest": 41,
#                 "bid": 1.17,
#                 "ask": 1.28,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617031606,
#                 "impliedVolatility": 0.23828886718749998,
#                 "inTheMoney": false
#               },
#               {
#                 "contractSymbol": "IBM210401P00137000",
#                 "strike": 137.0,
#                 "currency": "USD",
#                 "lastPrice": 1.99,
#                 "change": 0.33000004,
#                 "percentChange": 19.87952,
#                 "volume": 113,
#                 "openInterest": 19,
#                 "bid": 1.81,
#                 "ask": 1.94,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617030844,
#                 "impliedVolatility": 0.25879647460937505,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401P00138000",
#                 "strike": 138.0,
#                 "currency": "USD",
#                 "lastPrice": 2.54,
#                 "change": -0.31999993,
#                 "percentChange": -11.188809,
#                 "volume": 2,
#                 "openInterest": 6,
#                 "bid": 2.47,
#                 "ask": 2.83,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1617030778,
#                 "impliedVolatility": 0.3061592822265625,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401P00141000",
#                 "strike": 141.0,
#                 "currency": "USD",
#                 "lastPrice": 9.95,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "openInterest": 1,
#                 "bid": 5.1,
#                 "ask": 5.45,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616990635,
#                 "impliedVolatility": 0.38672488281249995,
#                 "inTheMoney": true
#               },
#               {
#                 "contractSymbol": "IBM210401P00150000",
#                 "strike": 150.0,
#                 "currency": "USD",
#                 "lastPrice": 17.5,
#                 "change": 0.0,
#                 "percentChange": 0.0,
#                 "openInterest": 1,
#                 "bid": 14.05,
#                 "ask": 14.35,
#                 "contractSize": "REGULAR",
#                 "expiration": 1617235200,
#                 "lastTradeDate": 1616691719,
#                 "impliedVolatility": 0.6552768847656252,
#                 "inTheMoney": true
#               }
#             ]
#           }
#         ]
#       }
#     ],
#     "error": null
#   }
# }

# %% [markdown]
# ## options endpoint: the yfinance compatible Options request
#
#
# The `compat.yfinance` module offers a `Options request` that is compatible with `yfinance`. It is derived from the `yahoo.Options` class, but it offers properties to access the information sections of the Financials data.

# %%
import virtual_finance_api.compat.yfinance.endpoints as yf

# %%
r = yf.Options(ticker)

# %%
client.request(r)
display(r.options)
# Out:
# ('2021-04-01',
#  '2021-04-09',
#  '2021-04-16',
#  '2021-04-23',
#  '2021-04-30',
#  '2021-05-07',
#  '2021-05-21',
#  '2021-06-18',
#  '2021-07-16',
#  '2021-09-17',
#  '2021-10-15',
#  '2022-01-21',
#  '2023-01-20')

# %%
display(r.option_chain('2021-04-01')[0])
# Out:
#         contractSymbol       lastTradeDate  strike  lastPrice    bid    ask  \
# 0   IBM210401C00065000 2021-03-19 17:37:38    65.0      65.15  70.65  71.05
# 1   IBM210401C00075000 2021-03-19 17:49:30    75.0      55.35  60.75  61.05
# 2   IBM210401C00090000 2021-03-19 17:58:30    90.0      40.40  45.70  46.05
# 3   IBM210401C00100000 2021-03-19 19:52:30   100.0      31.10  35.65  36.10
# 4   IBM210401C00108000 2021-03-24 14:14:19   108.0      24.10  27.65  28.15
# 5   IBM210401C00110000 2021-03-25 17:05:39   110.0      22.62  25.70  26.05
# 6   IBM210401C00111000 2021-03-24 14:00:56   111.0      20.75  24.80  25.15
# 7   IBM210401C00112000 2021-03-19 17:21:43   112.0      18.30  23.65  24.15
# 8   IBM210401C00114000 2021-03-25 17:11:23   114.0      18.75  21.55  21.95
# 9   IBM210401C00115000 2021-03-22 16:11:43   115.0      20.80  20.70  21.05
# 10  IBM210401C00116000 2021-03-26 17:38:04   116.0      19.06  19.75  20.05
# 11  IBM210401C00117000 2021-03-24 13:45:54   117.0      14.76  18.80  19.00
# 12  IBM210401C00118000 2021-03-29 14:59:35   118.0      18.00  17.75  18.15
# 13  IBM210401C00119000 2021-03-26 19:56:56   119.0      17.21  16.70  17.00
# 14  IBM210401C00120000 2021-03-26 17:14:34   120.0      14.97  15.70  16.00
# 15  IBM210401C00121000 2021-03-24 17:34:58   121.0      10.39  14.65  15.00
# 16  IBM210401C00122000 2021-03-26 14:05:36   122.0      11.95  13.75  14.05
# 17  IBM210401C00123000 2021-03-26 18:09:25   123.0      12.00  12.65  13.00
# 18  IBM210401C00124000 2021-03-29 15:05:16   124.0      12.19  11.80  12.10
# 19  IBM210401C00125000 2021-03-29 14:31:38   125.0      11.45  10.70  11.00
# 20  IBM210401C00126000 2021-03-26 18:19:56   126.0      10.95   9.75  10.10
# 21  IBM210401C00127000 2021-03-26 17:51:54   127.0       7.94   8.80   9.10
# 22  IBM210401C00128000 2021-03-29 15:13:47   128.0       7.86   7.80   8.10
# 23  IBM210401C00129000 2021-03-29 15:09:38   129.0       7.09   6.85   7.10
# 24  IBM210401C00130000 2021-03-29 15:17:53   130.0       5.99   5.95   6.25
# 25  IBM210401C00131000 2021-03-29 15:19:59   131.0       5.01   4.95   5.25
# 26  IBM210401C00132000 2021-03-29 14:53:45   132.0       4.50   4.00   4.25
# 27  IBM210401C00133000 2021-03-29 14:09:23   133.0       3.46   3.05   3.35
# 28  IBM210401C00134000 2021-03-29 15:13:27   134.0       2.35   2.22   2.53
# 29  IBM210401C00135000 2021-03-29 15:29:30   135.0       1.70   1.62   1.75
# 30  IBM210401C00136000 2021-03-29 15:29:10   136.0       1.10   1.01   1.14
# 31  IBM210401C00137000 2021-03-29 15:27:54   137.0       0.67   0.68   0.75
# 32  IBM210401C00138000 2021-03-29 15:09:25   138.0       0.41   0.40   0.44
# 33  IBM210401C00139000 2021-03-29 14:34:34   139.0       0.27   0.25   0.29
# 34  IBM210401C00140000 2021-03-29 15:22:45   140.0       0.16   0.17   0.19
# 35  IBM210401C00141000 2021-03-29 14:14:46   141.0       0.17   0.12   0.14
# 36  IBM210401C00142000 2021-03-29 13:30:01   142.0       0.14   0.09   0.11
# 37  IBM210401C00143000 2021-03-29 15:19:11   143.0       0.09   0.07   0.09
# 38  IBM210401C00145000 2021-03-29 15:17:43   145.0       0.05   0.05   0.06
# 39  IBM210401C00150000 2021-03-29 14:55:55   150.0       0.02   0.02   0.04
#
#       change  percentChange  volume  openInterest  impliedVolatility  \
# 0   0.000000       0.000000       3             4           0.000010
# 1   0.000000       0.000000      10            10           0.000010
# 2   0.000000       0.000000      13            13           0.000010
# 3   0.000000       0.000000       3            17           0.000010
# 4   0.000000       0.000000       1             4           0.000010
# 5   0.000000       0.000000       2            11           0.000010
# 6   0.000000       0.000000       1             2           0.000010
# 7   0.000000       0.000000      13            32           0.000010
# 8   0.000000       0.000000       2             1           0.000010
# 9   4.449999      27.217117       2            24           0.000010
# 10  0.000000       0.000000       1             4           0.000010
# 11  0.000000       0.000000       1             4           0.000010
# 12  4.850000      36.882133       3            18           0.000010
# 13  0.000000       0.000000       5            49           0.000010
# 14  0.000000       0.000000       2            37           0.000010
# 15  0.000000       0.000000      10           110           0.000010
# 16  0.000000       0.000000       8           151           0.000010
# 17  0.000000       0.000000      40           152           0.000010
# 18  2.169999      21.656677      12           239           0.000010
# 19  0.580000       5.335786       2           334           0.000010
# 20  1.960000      21.802002       4           165           0.000010
# 21  0.000000       0.000000      17           146           0.000010
# 22 -0.539999      -6.428566       4           363           0.000010
# 23  0.190000       2.753624      27           409           0.000010
# 24 -0.310000      -4.920641      47          1976           0.255867
# 25 -0.090000      -1.764700      11           466           0.220711
# 26  0.380000       9.223304      39           748           0.185555
# 27  0.220000       6.790124      19           275           0.192391
# 28 -0.580000     -19.795227      81           381           0.196297
# 29 -0.510000     -23.076921      98           711           0.185311
# 30 -0.400000     -26.666664     184           483           0.183358
# 31 -0.280000     -29.473680     585           619           0.194344
# 32 -0.300000     -42.253520     451           881           0.195809
# 33 -0.120000     -30.769224      90           107           0.210457
# 34 -0.130000     -44.827587     499           705           0.223641
# 35  0.000000       0.000000      72           110           0.243172
# 36  0.050000      55.555550      21             3           0.263679
# 37 -0.010000      -9.999997     131             3           0.285163
# 38 -0.030000     -37.499996      34           202           0.324226
# 39 -0.010000     -33.333336      10             5           0.435553
#
#     inTheMoney contractSize currency
# 0         True      REGULAR      USD
# 1         True      REGULAR      USD
# 2         True      REGULAR      USD
# 3         True      REGULAR      USD
# 4         True      REGULAR      USD
# 5         True      REGULAR      USD
# 6         True      REGULAR      USD
# 7         True      REGULAR      USD
# 8         True      REGULAR      USD
# 9         True      REGULAR      USD
# 10        True      REGULAR      USD
# 11        True      REGULAR      USD
# 12        True      REGULAR      USD
# 13        True      REGULAR      USD
# 14        True      REGULAR      USD
# 15        True      REGULAR      USD
# 16        True      REGULAR      USD
# 17        True      REGULAR      USD
# 18        True      REGULAR      USD
# 19        True      REGULAR      USD
# 20        True      REGULAR      USD
# 21        True      REGULAR      USD
# 22        True      REGULAR      USD
# 23        True      REGULAR      USD
# 24        True      REGULAR      USD
# 25        True      REGULAR      USD
# 26        True      REGULAR      USD
# 27        True      REGULAR      USD
# 28        True      REGULAR      USD
# 29        True      REGULAR      USD
# 30        True      REGULAR      USD
# 31       False      REGULAR      USD
# 32       False      REGULAR      USD
# 33       False      REGULAR      USD
# 34       False      REGULAR      USD
# 35       False      REGULAR      USD
# 36       False      REGULAR      USD
# 37       False      REGULAR      USD
# 38       False      REGULAR      USD
# 39       False      REGULAR      USD

# %% [markdown]
# [index](./index.ipynb) | [yhoo-profile](./profile.ipynb) | [yhoo-financials](./financials.ipynb) | [yhoo-holders](./holders.ipynb) | [yhoo-options](./options.ipynb) | [yhoo-history](./history.ipynb)
